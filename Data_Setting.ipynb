# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

from scipy.sparse import hstack

# %%
sold0 = pd.read_csv("CRMLSSold202401.csv")
sold1 = pd.read_csv("CRMLSSold202402.csv")
sold2 = pd.read_csv("CRMLSSold202403.csv")
sold3 = pd.read_csv("CRMLSSold202404.csv")
sold4 = pd.read_csv("CRMLSSold202405_filled.csv")
sold5 = pd.read_csv("CRMLSSold202406_filled.csv")
sold6 = pd.read_csv("CRMLSSold202407_filled.csv")
sold7 = pd.read_csv("CRMLSSold202408.csv")
sold8 = pd.read_csv("CRMLSSold202409.csv")
sold9 = pd.read_csv("CRMLSSold202410.csv")
sold10 = pd.read_csv("CRMLSSold202411.csv")
sold11 = pd.read_csv("CRMLSSold202412.csv")
sold12 = pd.read_csv("CRMLSSold202501_filled.csv")
sold13 = pd.read_csv("CRMLSSold202502.csv")
sold14 = pd.read_csv("CRMLSSold202503.csv")
sold15 = pd.read_csv("CRMLSSold202504.csv")
sold16 = pd.read_csv("CRMLSSold202505.csv")
sold17 = pd.read_csv("CRMLSSold202506.csv")
sold18 = pd.read_csv("CRMLSSold202507.csv")
sold19 = pd.read_csv("CRMLSSold202508.csv")
sold20 = pd.read_csv("CRMLSSold202509.csv")
sold21 = pd.read_csv("CRMLSSold202510.csv")
sold22 = pd.read_csv("CRMLSSold202511.csv")
sold23 = pd.read_csv("CRMLSSold202512.csv")
sold24 = pd.read_csv("CRMLSSold202601.csv")
sold25 = pd.read_csv("CRMLSSold202602.csv")
sold26 = pd.read_csv("CRMLSSold202603.csv")
sold27 = pd.read_csv("CRMLSSold202604.csv")
sold28 = pd.read_csv("CRMLSSold202605.csv")
# Out:
# C:\Users\junki\AppData\Local\Temp\ipykernel_9880\1667112100.py:4: DtypeWarning: Columns (0: WaterfrontYN, 1: ElementarySchool, 2: BuilderName, 3: CoBuyerAgentFirstName, 4: PostalCode) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold3 = pd.read_csv("CRMLSSold202404.csv")
# C:\Users\junki\AppData\Local\Temp\ipykernel_9880\1667112100.py:18: DtypeWarning: Columns (0: WaterfrontYN) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold17 = pd.read_csv("CRMLSSold202506.csv")
# C:\Users\junki\AppData\Local\Temp\ipykernel_9880\1667112100.py:25: DtypeWarning: Columns (0: WaterfrontYN, 1: PostalCode) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold24 = pd.read_csv("CRMLSSold202601.csv")

# %%
print(sold0.shape)
print(sold1.shape)
print(sold2.shape)
print(sold3.shape)
print(sold4.shape)
print(sold5.shape)
print(sold6.shape)
print(sold7.shape)
print(sold8.shape)
print(sold9.shape)
print(sold10.shape)
print(sold11.shape)
print(sold12.shape)
print(sold13.shape)
print(sold14.shape)
print(sold15.shape)
print(sold16.shape)
print(sold17.shape)
print(sold18.shape)
print(sold19.shape)
print(sold20.shape)
print(sold21.shape)
print(sold22.shape)
print(sold23.shape)
print(sold24.shape)
print(sold25.shape)
print(sold26.shape)
print(sold27.shape)
print(sold28.shape)
# Out:
# (17976, 80)
# (19925, 78)
# (23276, 78)
# (24640, 78)
# (26487, 80)
# (24328, 80)
# (26240, 80)
# (24558, 78)
# (21267, 78)
# (23274, 78)
# (20279, 78)
# (20241, 78)
# (18738, 80)
# (18702, 78)
# (21445, 78)
# (23262, 78)
# (23154, 78)
# (22883, 78)
# (23646, 78)
# (22972, 78)
# (22443, 78)
# (23233, 78)
# (19088, 78)
# (20538, 78)
# (16487, 78)
# (19010, 80)
# (23372, 80)
# (24261, 80)
# (24191, 79)

# %%
sold = [sold0, sold1, sold2, sold3, sold4, sold5, sold6, sold7, sold8, sold9, sold10, sold11, sold12, sold13, sold14, sold15, sold16, sold17, sold18, sold19, sold20, sold21, sold22, sold23, sold24, sold25, sold26, sold27, sold28]

for i in range(len(sold)):
    for j in range(i+1,len(sold)):
        if i != j:
            print(f"sold[{i}] - sold[{j}]")
            print(set(sold[i].columns) - set(sold[j].columns))

            print(f"sold[{j}] - sold[{i}]")
            print(set(sold[j].columns) - set(sold[i].columns))
# Out:
# sold[0] - sold[1]
# {'OriginatingSystemSubName', 'ListAgentAOR', 'OriginatingSystemName', 'BuyerAgentAOR'}
# sold[1] - sold[0]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[0] - sold[2]
# {'OriginatingSystemSubName', 'ListAgentAOR', 'OriginatingSystemName', 'BuyerAgentAOR'}
# sold[2] - sold[0]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[0] - sold[3]
# {'OriginatingSystemSubName', 'ListAgentAOR', 'OriginatingSystemName', 'BuyerAgentAOR'}
# sold[3] - sold[0]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[0] - sold[4]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[4] - sold[0]
# {'latfilled', 'lonfilled'}
# sold[0] - sold[5]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[5] - sold[0]
# {'latfilled', 'lonfilled'}
# sold[0] - sold[6]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[6] - sold[0]
# {'latfilled', 'lonfilled'}
# sold[0] - sold[7]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[7] - sold[0]
# set()
# sold[0] - sold[8]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[8] - sold[0]
# set()
# sold[0] - sold[9]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[9] - sold[0]
# set()
# sold[0] - sold[10]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[10] - sold[0]
# set()
# sold[0] - sold[11]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[11] - sold[0]
# set()
# sold[0] - sold[12]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[12] - sold[0]
# {'latfilled', 'lonfilled'}
# sold[0] - sold[13]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[13] - sold[0]
# set()
# sold[0] - sold[14]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[14] - sold[0]
# set()
# sold[0] - sold[15]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[15] - sold[0]
# set()
# sold[0] - sold[16]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[16] - sold[0]
# set()
# sold[0] - sold[17]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[17] - sold[0]
# set()
# sold[0] - sold[18]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[18] - sold[0]
# set()
# sold[0] - sold[19]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[19] - sold[0]
# set()
# sold[0] - sold[20]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[20] - sold[0]
# set()
# sold[0] - sold[21]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[21] - sold[0]
# set()
# sold[0] - sold[22]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[22] - sold[0]
# set()
# sold[0] - sold[23]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[23] - sold[0]
# set()
# sold[0] - sold[24]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[24] - sold[0]
# set()
# sold[0] - sold[25]
# set()
# sold[25] - sold[0]
# set()
# sold[0] - sold[26]
# set()
# sold[26] - sold[0]
# set()
# sold[0] - sold[27]
# set()
# sold[27] - sold[0]
# set()
# sold[0] - sold[28]
# {'ListAgentEmail'}
# sold[28] - sold[0]
# set()
# sold[1] - sold[2]
# set()
# sold[2] - sold[1]
# set()
# sold[1] - sold[3]
# set()
# sold[3] - sold[1]
# set()
# sold[1] - sold[4]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[4] - sold[1]
# {'lonfilled', 'latfilled', 'BuyerAgentAOR', 'ListAgentAOR'}
# sold[1] - sold[5]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[5] - sold[1]
# {'lonfilled', 'latfilled', 'BuyerAgentAOR', 'ListAgentAOR'}
# sold[1] - sold[6]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[6] - sold[1]
# {'lonfilled', 'latfilled', 'BuyerAgentAOR', 'ListAgentAOR'}
# sold[1] - sold[7]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[7] - sold[1]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[1] - sold[8]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[8] - sold[1]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[1] - sold[9]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[9] - sold[1]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[1] - sold[10]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[10] - sold[1]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[1] - sold[11]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[11] - sold[1]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[1] - sold[12]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[12] - sold[1]
# {'lonfilled', 'latfilled', 'BuyerAgentAOR', 'ListAgentAOR'}
# sold[1] - sold[13]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[13] - sold[1]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[1] - sold[14]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[14] - sold[1]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[1] - sold[15]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[15] - sold[1]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[1] - sold[16]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[16] - sold[1]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[1] - sold[17]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[17] - sold[1]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[1] - sold[18]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[18] - sold[1]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[1] - sold[19]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[19] - sold[1]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[1] - sold[20]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[20] - sold[1]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[1] - sold[21]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[21] - sold[1]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[1] - sold[22]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[22] - sold[1]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[1] - sold[23]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[23] - sold[1]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[1] - sold[24]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[24] - sold[1]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[1] - sold[25]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[25] - sold[1]
# {'OriginatingSystemSubName', 'ListAgentAOR', 'OriginatingSystemName', 'BuyerAgentAOR'}
# sold[1] - sold[26]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[26] - sold[1]
# {'OriginatingSystemSubName', 'ListAgentAOR', 'OriginatingSystemName', 'BuyerAgentAOR'}
# sold[1] - sold[27]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[27] - sold[1]
# {'OriginatingSystemSubName', 'ListAgentAOR', 'OriginatingSystemName', 'BuyerAgentAOR'}
# sold[1] - sold[28]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation', 'ListAgentEmail'}
# sold[28] - sold[1]
# {'OriginatingSystemSubName', 'ListAgentAOR', 'OriginatingSystemName', 'BuyerAgentAOR'}
# sold[2] - sold[3]
# set()
# sold[3] - sold[2]
# set()
# sold[2] - sold[4]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[4] - sold[2]
# {'lonfilled', 'latfilled', 'BuyerAgentAOR', 'ListAgentAOR'}
# sold[2] - sold[5]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[5] - sold[2]
# {'lonfilled', 'latfilled', 'BuyerAgentAOR', 'ListAgentAOR'}
# sold[2] - sold[6]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[6] - sold[2]
# {'lonfilled', 'latfilled', 'BuyerAgentAOR', 'ListAgentAOR'}
# sold[2] - sold[7]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[7] - sold[2]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[2] - sold[8]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[8] - sold[2]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[2] - sold[9]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[9] - sold[2]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[2] - sold[10]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[10] - sold[2]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[2] - sold[11]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[11] - sold[2]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[2] - sold[12]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[12] - sold[2]
# {'lonfilled', 'latfilled', 'BuyerAgentAOR', 'ListAgentAOR'}
# sold[2] - sold[13]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[13] - sold[2]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[2] - sold[14]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[14] - sold[2]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[2] - sold[15]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[15] - sold[2]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[2] - sold[16]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[16] - sold[2]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[2] - sold[17]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[17] - sold[2]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[2] - sold[18]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[18] - sold[2]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[2] - sold[19]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[19] - sold[2]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[2] - sold[20]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[20] - sold[2]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[2] - sold[21]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[21] - sold[2]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[2] - sold[22]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[22] - sold[2]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[2] - sold[23]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[23] - sold[2]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[2] - sold[24]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[24] - sold[2]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[2] - sold[25]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[25] - sold[2]
# {'OriginatingSystemSubName', 'ListAgentAOR', 'OriginatingSystemName', 'BuyerAgentAOR'}
# sold[2] - sold[26]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[26] - sold[2]
# {'OriginatingSystemSubName', 'ListAgentAOR', 'OriginatingSystemName', 'BuyerAgentAOR'}
# sold[2] - sold[27]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[27] - sold[2]
# {'OriginatingSystemSubName', 'ListAgentAOR', 'OriginatingSystemName', 'BuyerAgentAOR'}
# sold[2] - sold[28]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation', 'ListAgentEmail'}
# sold[28] - sold[2]
# {'OriginatingSystemSubName', 'ListAgentAOR', 'OriginatingSystemName', 'BuyerAgentAOR'}
# sold[3] - sold[4]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[4] - sold[3]
# {'lonfilled', 'latfilled', 'BuyerAgentAOR', 'ListAgentAOR'}
# sold[3] - sold[5]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[5] - sold[3]
# {'lonfilled', 'latfilled', 'BuyerAgentAOR', 'ListAgentAOR'}
# sold[3] - sold[6]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[6] - sold[3]
# {'lonfilled', 'latfilled', 'BuyerAgentAOR', 'ListAgentAOR'}
# sold[3] - sold[7]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[7] - sold[3]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[3] - sold[8]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[8] - sold[3]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[3] - sold[9]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[9] - sold[3]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[3] - sold[10]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[10] - sold[3]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[3] - sold[11]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[11] - sold[3]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[3] - sold[12]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[12] - sold[3]
# {'lonfilled', 'latfilled', 'BuyerAgentAOR', 'ListAgentAOR'}
# sold[3] - sold[13]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[13] - sold[3]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[3] - sold[14]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[14] - sold[3]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[3] - sold[15]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[15] - sold[3]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[3] - sold[16]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[16] - sold[3]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[3] - sold[17]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[17] - sold[3]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[3] - sold[18]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[18] - sold[3]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[3] - sold[19]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[19] - sold[3]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[3] - sold[20]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[20] - sold[3]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[3] - sold[21]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[21] - sold[3]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[3] - sold[22]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[22] - sold[3]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[3] - sold[23]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[23] - sold[3]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[3] - sold[24]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[24] - sold[3]
# {'BuyerAgentAOR', 'ListAgentAOR'}
# sold[3] - sold[25]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[25] - sold[3]
# {'OriginatingSystemSubName', 'ListAgentAOR', 'OriginatingSystemName', 'BuyerAgentAOR'}
# sold[3] - sold[26]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[26] - sold[3]
# {'OriginatingSystemSubName', 'ListAgentAOR', 'OriginatingSystemName', 'BuyerAgentAOR'}
# sold[3] - sold[27]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# sold[27] - sold[3]
# {'OriginatingSystemSubName', 'ListAgentAOR', 'OriginatingSystemName', 'BuyerAgentAOR'}
# sold[3] - sold[28]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation', 'ListAgentEmail'}
# sold[28] - sold[3]
# {'OriginatingSystemSubName', 'ListAgentAOR', 'OriginatingSystemName', 'BuyerAgentAOR'}
# sold[4] - sold[5]
# set()
# sold[5] - sold[4]
# set()
# sold[4] - sold[6]
# set()
# sold[6] - sold[4]
# set()
# sold[4] - sold[7]
# {'latfilled', 'lonfilled'}
# sold[7] - sold[4]
# set()
# sold[4] - sold[8]
# {'latfilled', 'lonfilled'}
# sold[8] - sold[4]
# set()
# sold[4] - sold[9]
# {'latfilled', 'lonfilled'}
# sold[9] - sold[4]
# set()
# sold[4] - sold[10]
# {'latfilled', 'lonfilled'}
# sold[10] - sold[4]
# set()
# sold[4] - sold[11]
# {'latfilled', 'lonfilled'}
# sold[11] - sold[4]
# set()
# sold[4] - sold[12]
# set()
# sold[12] - sold[4]
# set()
# sold[4] - sold[13]
# {'latfilled', 'lonfilled'}
# sold[13] - sold[4]
# set()
# sold[4] - sold[14]
# {'latfilled', 'lonfilled'}
# sold[14] - sold[4]
# set()
# sold[4] - sold[15]
# {'latfilled', 'lonfilled'}
# sold[15] - sold[4]
# set()
# sold[4] - sold[16]
# {'latfilled', 'lonfilled'}
# sold[16] - sold[4]
# set()
# sold[4] - sold[17]
# {'latfilled', 'lonfilled'}
# sold[17] - sold[4]
# set()
# sold[4] - sold[18]
# {'latfilled', 'lonfilled'}
# sold[18] - sold[4]
# set()
# sold[4] - sold[19]
# {'latfilled', 'lonfilled'}
# sold[19] - sold[4]
# set()
# sold[4] - sold[20]
# {'latfilled', 'lonfilled'}
# sold[20] - sold[4]
# set()
# sold[4] - sold[21]
# {'latfilled', 'lonfilled'}
# sold[21] - sold[4]
# set()
# sold[4] - sold[22]
# {'latfilled', 'lonfilled'}
# sold[22] - sold[4]
# set()
# sold[4] - sold[23]
# {'latfilled', 'lonfilled'}
# sold[23] - sold[4]
# set()
# sold[4] - sold[24]
# {'latfilled', 'lonfilled'}
# sold[24] - sold[4]
# set()
# sold[4] - sold[25]
# {'latfilled', 'lonfilled'}
# sold[25] - sold[4]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[4] - sold[26]
# {'latfilled', 'lonfilled'}
# sold[26] - sold[4]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[4] - sold[27]
# {'latfilled', 'lonfilled'}
# sold[27] - sold[4]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[4] - sold[28]
# {'latfilled', 'lonfilled', 'ListAgentEmail'}
# sold[28] - sold[4]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[5] - sold[6]
# set()
# sold[6] - sold[5]
# set()
# sold[5] - sold[7]
# {'latfilled', 'lonfilled'}
# sold[7] - sold[5]
# set()
# sold[5] - sold[8]
# {'latfilled', 'lonfilled'}
# sold[8] - sold[5]
# set()
# sold[5] - sold[9]
# {'latfilled', 'lonfilled'}
# sold[9] - sold[5]
# set()
# sold[5] - sold[10]
# {'latfilled', 'lonfilled'}
# sold[10] - sold[5]
# set()
# sold[5] - sold[11]
# {'latfilled', 'lonfilled'}
# sold[11] - sold[5]
# set()
# sold[5] - sold[12]
# set()
# sold[12] - sold[5]
# set()
# sold[5] - sold[13]
# {'latfilled', 'lonfilled'}
# sold[13] - sold[5]
# set()
# sold[5] - sold[14]
# {'latfilled', 'lonfilled'}
# sold[14] - sold[5]
# set()
# sold[5] - sold[15]
# {'latfilled', 'lonfilled'}
# sold[15] - sold[5]
# set()
# sold[5] - sold[16]
# {'latfilled', 'lonfilled'}
# sold[16] - sold[5]
# set()
# sold[5] - sold[17]
# {'latfilled', 'lonfilled'}
# sold[17] - sold[5]
# set()
# sold[5] - sold[18]
# {'latfilled', 'lonfilled'}
# sold[18] - sold[5]
# set()
# sold[5] - sold[19]
# {'latfilled', 'lonfilled'}
# sold[19] - sold[5]
# set()
# sold[5] - sold[20]
# {'latfilled', 'lonfilled'}
# sold[20] - sold[5]
# set()
# sold[5] - sold[21]
# {'latfilled', 'lonfilled'}
# sold[21] - sold[5]
# set()
# sold[5] - sold[22]
# {'latfilled', 'lonfilled'}
# sold[22] - sold[5]
# set()
# sold[5] - sold[23]
# {'latfilled', 'lonfilled'}
# sold[23] - sold[5]
# set()
# sold[5] - sold[24]
# {'latfilled', 'lonfilled'}
# sold[24] - sold[5]
# set()
# sold[5] - sold[25]
# {'latfilled', 'lonfilled'}
# sold[25] - sold[5]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[5] - sold[26]
# {'latfilled', 'lonfilled'}
# sold[26] - sold[5]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[5] - sold[27]
# {'latfilled', 'lonfilled'}
# sold[27] - sold[5]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[5] - sold[28]
# {'latfilled', 'lonfilled', 'ListAgentEmail'}
# sold[28] - sold[5]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[6] - sold[7]
# {'latfilled', 'lonfilled'}
# sold[7] - sold[6]
# set()
# sold[6] - sold[8]
# {'latfilled', 'lonfilled'}
# sold[8] - sold[6]
# set()
# sold[6] - sold[9]
# {'latfilled', 'lonfilled'}
# sold[9] - sold[6]
# set()
# sold[6] - sold[10]
# {'latfilled', 'lonfilled'}
# sold[10] - sold[6]
# set()
# sold[6] - sold[11]
# {'latfilled', 'lonfilled'}
# sold[11] - sold[6]
# set()
# sold[6] - sold[12]
# set()
# sold[12] - sold[6]
# set()
# sold[6] - sold[13]
# {'latfilled', 'lonfilled'}
# sold[13] - sold[6]
# set()
# sold[6] - sold[14]
# {'latfilled', 'lonfilled'}
# sold[14] - sold[6]
# set()
# sold[6] - sold[15]
# {'latfilled', 'lonfilled'}
# sold[15] - sold[6]
# set()
# sold[6] - sold[16]
# {'latfilled', 'lonfilled'}
# sold[16] - sold[6]
# set()
# sold[6] - sold[17]
# {'latfilled', 'lonfilled'}
# sold[17] - sold[6]
# set()
# sold[6] - sold[18]
# {'latfilled', 'lonfilled'}
# sold[18] - sold[6]
# set()
# sold[6] - sold[19]
# {'latfilled', 'lonfilled'}
# sold[19] - sold[6]
# set()
# sold[6] - sold[20]
# {'latfilled', 'lonfilled'}
# sold[20] - sold[6]
# set()
# sold[6] - sold[21]
# {'latfilled', 'lonfilled'}
# sold[21] - sold[6]
# set()
# sold[6] - sold[22]
# {'latfilled', 'lonfilled'}
# sold[22] - sold[6]
# set()
# sold[6] - sold[23]
# {'latfilled', 'lonfilled'}
# sold[23] - sold[6]
# set()
# sold[6] - sold[24]
# {'latfilled', 'lonfilled'}
# sold[24] - sold[6]
# set()
# sold[6] - sold[25]
# {'latfilled', 'lonfilled'}
# sold[25] - sold[6]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[6] - sold[26]
# {'latfilled', 'lonfilled'}
# sold[26] - sold[6]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[6] - sold[27]
# {'latfilled', 'lonfilled'}
# sold[27] - sold[6]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[6] - sold[28]
# {'latfilled', 'lonfilled', 'ListAgentEmail'}
# sold[28] - sold[6]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[7] - sold[8]
# set()
# sold[8] - sold[7]
# set()
# sold[7] - sold[9]
# set()
# sold[9] - sold[7]
# set()
# sold[7] - sold[10]
# set()
# sold[10] - sold[7]
# set()
# sold[7] - sold[11]
# set()
# sold[11] - sold[7]
# set()
# sold[7] - sold[12]
# set()
# sold[12] - sold[7]
# {'latfilled', 'lonfilled'}
# sold[7] - sold[13]
# set()
# sold[13] - sold[7]
# set()
# sold[7] - sold[14]
# set()
# sold[14] - sold[7]
# set()
# sold[7] - sold[15]
# set()
# sold[15] - sold[7]
# set()
# sold[7] - sold[16]
# set()
# sold[16] - sold[7]
# set()
# sold[7] - sold[17]
# set()
# sold[17] - sold[7]
# set()
# sold[7] - sold[18]
# set()
# sold[18] - sold[7]
# set()
# sold[7] - sold[19]
# set()
# sold[19] - sold[7]
# set()
# sold[7] - sold[20]
# set()
# sold[20] - sold[7]
# set()
# sold[7] - sold[21]
# set()
# sold[21] - sold[7]
# set()
# sold[7] - sold[22]
# set()
# sold[22] - sold[7]
# set()
# sold[7] - sold[23]
# set()
# sold[23] - sold[7]
# set()
# sold[7] - sold[24]
# set()
# sold[24] - sold[7]
# set()
# sold[7] - sold[25]
# set()
# sold[25] - sold[7]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[7] - sold[26]
# set()
# sold[26] - sold[7]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[7] - sold[27]
# set()
# sold[27] - sold[7]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[7] - sold[28]
# {'ListAgentEmail'}
# sold[28] - sold[7]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[8] - sold[9]
# set()
# sold[9] - sold[8]
# set()
# sold[8] - sold[10]
# set()
# sold[10] - sold[8]
# set()
# sold[8] - sold[11]
# set()
# sold[11] - sold[8]
# set()
# sold[8] - sold[12]
# set()
# sold[12] - sold[8]
# {'latfilled', 'lonfilled'}
# sold[8] - sold[13]
# set()
# sold[13] - sold[8]
# set()
# sold[8] - sold[14]
# set()
# sold[14] - sold[8]
# set()
# sold[8] - sold[15]
# set()
# sold[15] - sold[8]
# set()
# sold[8] - sold[16]
# set()
# sold[16] - sold[8]
# set()
# sold[8] - sold[17]
# set()
# sold[17] - sold[8]
# set()
# sold[8] - sold[18]
# set()
# sold[18] - sold[8]
# set()
# sold[8] - sold[19]
# set()
# sold[19] - sold[8]
# set()
# sold[8] - sold[20]
# set()
# sold[20] - sold[8]
# set()
# sold[8] - sold[21]
# set()
# sold[21] - sold[8]
# set()
# sold[8] - sold[22]
# set()
# sold[22] - sold[8]
# set()
# sold[8] - sold[23]
# set()
# sold[23] - sold[8]
# set()
# sold[8] - sold[24]
# set()
# sold[24] - sold[8]
# set()
# sold[8] - sold[25]
# set()
# sold[25] - sold[8]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[8] - sold[26]
# set()
# sold[26] - sold[8]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[8] - sold[27]
# set()
# sold[27] - sold[8]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[8] - sold[28]
# {'ListAgentEmail'}
# sold[28] - sold[8]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[9] - sold[10]
# set()
# sold[10] - sold[9]
# set()
# sold[9] - sold[11]
# set()
# sold[11] - sold[9]
# set()
# sold[9] - sold[12]
# set()
# sold[12] - sold[9]
# {'latfilled', 'lonfilled'}
# sold[9] - sold[13]
# set()
# sold[13] - sold[9]
# set()
# sold[9] - sold[14]
# set()
# sold[14] - sold[9]
# set()
# sold[9] - sold[15]
# set()
# sold[15] - sold[9]
# set()
# sold[9] - sold[16]
# set()
# sold[16] - sold[9]
# set()
# sold[9] - sold[17]
# set()
# sold[17] - sold[9]
# set()
# sold[9] - sold[18]
# set()
# sold[18] - sold[9]
# set()
# sold[9] - sold[19]
# set()
# sold[19] - sold[9]
# set()
# sold[9] - sold[20]
# set()
# sold[20] - sold[9]
# set()
# sold[9] - sold[21]
# set()
# sold[21] - sold[9]
# set()
# sold[9] - sold[22]
# set()
# sold[22] - sold[9]
# set()
# sold[9] - sold[23]
# set()
# sold[23] - sold[9]
# set()
# sold[9] - sold[24]
# set()
# sold[24] - sold[9]
# set()
# sold[9] - sold[25]
# set()
# sold[25] - sold[9]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[9] - sold[26]
# set()
# sold[26] - sold[9]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[9] - sold[27]
# set()
# sold[27] - sold[9]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[9] - sold[28]
# {'ListAgentEmail'}
# sold[28] - sold[9]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[10] - sold[11]
# set()
# sold[11] - sold[10]
# set()
# sold[10] - sold[12]
# set()
# sold[12] - sold[10]
# {'latfilled', 'lonfilled'}
# sold[10] - sold[13]
# set()
# sold[13] - sold[10]
# set()
# sold[10] - sold[14]
# set()
# sold[14] - sold[10]
# set()
# sold[10] - sold[15]
# set()
# sold[15] - sold[10]
# set()
# sold[10] - sold[16]
# set()
# sold[16] - sold[10]
# set()
# sold[10] - sold[17]
# set()
# sold[17] - sold[10]
# set()
# sold[10] - sold[18]
# set()
# sold[18] - sold[10]
# set()
# sold[10] - sold[19]
# set()
# sold[19] - sold[10]
# set()
# sold[10] - sold[20]
# set()
# sold[20] - sold[10]
# set()
# sold[10] - sold[21]
# set()
# sold[21] - sold[10]
# set()
# sold[10] - sold[22]
# set()
# sold[22] - sold[10]
# set()
# sold[10] - sold[23]
# set()
# sold[23] - sold[10]
# set()
# sold[10] - sold[24]
# set()
# sold[24] - sold[10]
# set()
# sold[10] - sold[25]
# set()
# sold[25] - sold[10]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[10] - sold[26]
# set()
# sold[26] - sold[10]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[10] - sold[27]
# set()
# sold[27] - sold[10]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[10] - sold[28]
# {'ListAgentEmail'}
# sold[28] - sold[10]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[11] - sold[12]
# set()
# sold[12] - sold[11]
# {'latfilled', 'lonfilled'}
# sold[11] - sold[13]
# set()
# sold[13] - sold[11]
# set()
# sold[11] - sold[14]
# set()
# sold[14] - sold[11]
# set()
# sold[11] - sold[15]
# set()
# sold[15] - sold[11]
# set()
# sold[11] - sold[16]
# set()
# sold[16] - sold[11]
# set()
# sold[11] - sold[17]
# set()
# sold[17] - sold[11]
# set()
# sold[11] - sold[18]
# set()
# sold[18] - sold[11]
# set()
# sold[11] - sold[19]
# set()
# sold[19] - sold[11]
# set()
# sold[11] - sold[20]
# set()
# sold[20] - sold[11]
# set()
# sold[11] - sold[21]
# set()
# sold[21] - sold[11]
# set()
# sold[11] - sold[22]
# set()
# sold[22] - sold[11]
# set()
# sold[11] - sold[23]
# set()
# sold[23] - sold[11]
# set()
# sold[11] - sold[24]
# set()
# sold[24] - sold[11]
# set()
# sold[11] - sold[25]
# set()
# sold[25] - sold[11]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[11] - sold[26]
# set()
# sold[26] - sold[11]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[11] - sold[27]
# set()
# sold[27] - sold[11]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[11] - sold[28]
# {'ListAgentEmail'}
# sold[28] - sold[11]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[12] - sold[13]
# {'latfilled', 'lonfilled'}
# sold[13] - sold[12]
# set()
# sold[12] - sold[14]
# {'latfilled', 'lonfilled'}
# sold[14] - sold[12]
# set()
# sold[12] - sold[15]
# {'latfilled', 'lonfilled'}
# sold[15] - sold[12]
# set()
# sold[12] - sold[16]
# {'latfilled', 'lonfilled'}
# sold[16] - sold[12]
# set()
# sold[12] - sold[17]
# {'latfilled', 'lonfilled'}
# sold[17] - sold[12]
# set()
# sold[12] - sold[18]
# {'latfilled', 'lonfilled'}
# sold[18] - sold[12]
# set()
# sold[12] - sold[19]
# {'latfilled', 'lonfilled'}
# sold[19] - sold[12]
# set()
# sold[12] - sold[20]
# {'latfilled', 'lonfilled'}
# sold[20] - sold[12]
# set()
# sold[12] - sold[21]
# {'latfilled', 'lonfilled'}
# sold[21] - sold[12]
# set()
# sold[12] - sold[22]
# {'latfilled', 'lonfilled'}
# sold[22] - sold[12]
# set()
# sold[12] - sold[23]
# {'latfilled', 'lonfilled'}
# sold[23] - sold[12]
# set()
# sold[12] - sold[24]
# {'latfilled', 'lonfilled'}
# sold[24] - sold[12]
# set()
# sold[12] - sold[25]
# {'latfilled', 'lonfilled'}
# sold[25] - sold[12]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[12] - sold[26]
# {'latfilled', 'lonfilled'}
# sold[26] - sold[12]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[12] - sold[27]
# {'latfilled', 'lonfilled'}
# sold[27] - sold[12]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[12] - sold[28]
# {'latfilled', 'lonfilled', 'ListAgentEmail'}
# sold[28] - sold[12]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[13] - sold[14]
# set()
# sold[14] - sold[13]
# set()
# sold[13] - sold[15]
# set()
# sold[15] - sold[13]
# set()
# sold[13] - sold[16]
# set()
# sold[16] - sold[13]
# set()
# sold[13] - sold[17]
# set()
# sold[17] - sold[13]
# set()
# sold[13] - sold[18]
# set()
# sold[18] - sold[13]
# set()
# sold[13] - sold[19]
# set()
# sold[19] - sold[13]
# set()
# sold[13] - sold[20]
# set()
# sold[20] - sold[13]
# set()
# sold[13] - sold[21]
# set()
# sold[21] - sold[13]
# set()
# sold[13] - sold[22]
# set()
# sold[22] - sold[13]
# set()
# sold[13] - sold[23]
# set()
# sold[23] - sold[13]
# set()
# sold[13] - sold[24]
# set()
# sold[24] - sold[13]
# set()
# sold[13] - sold[25]
# set()
# sold[25] - sold[13]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[13] - sold[26]
# set()
# sold[26] - sold[13]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[13] - sold[27]
# set()
# sold[27] - sold[13]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[13] - sold[28]
# {'ListAgentEmail'}
# sold[28] - sold[13]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[14] - sold[15]
# set()
# sold[15] - sold[14]
# set()
# sold[14] - sold[16]
# set()
# sold[16] - sold[14]
# set()
# sold[14] - sold[17]
# set()
# sold[17] - sold[14]
# set()
# sold[14] - sold[18]
# set()
# sold[18] - sold[14]
# set()
# sold[14] - sold[19]
# set()
# sold[19] - sold[14]
# set()
# sold[14] - sold[20]
# set()
# sold[20] - sold[14]
# set()
# sold[14] - sold[21]
# set()
# sold[21] - sold[14]
# set()
# sold[14] - sold[22]
# set()
# sold[22] - sold[14]
# set()
# sold[14] - sold[23]
# set()
# sold[23] - sold[14]
# set()
# sold[14] - sold[24]
# set()
# sold[24] - sold[14]
# set()
# sold[14] - sold[25]
# set()
# sold[25] - sold[14]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[14] - sold[26]
# set()
# sold[26] - sold[14]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[14] - sold[27]
# set()
# sold[27] - sold[14]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[14] - sold[28]
# {'ListAgentEmail'}
# sold[28] - sold[14]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[15] - sold[16]
# set()
# sold[16] - sold[15]
# set()
# sold[15] - sold[17]
# set()
# sold[17] - sold[15]
# set()
# sold[15] - sold[18]
# set()
# sold[18] - sold[15]
# set()
# sold[15] - sold[19]
# set()
# sold[19] - sold[15]
# set()
# sold[15] - sold[20]
# set()
# sold[20] - sold[15]
# set()
# sold[15] - sold[21]
# set()
# sold[21] - sold[15]
# set()
# sold[15] - sold[22]
# set()
# sold[22] - sold[15]
# set()
# sold[15] - sold[23]
# set()
# sold[23] - sold[15]
# set()
# sold[15] - sold[24]
# set()
# sold[24] - sold[15]
# set()
# sold[15] - sold[25]
# set()
# sold[25] - sold[15]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[15] - sold[26]
# set()
# sold[26] - sold[15]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[15] - sold[27]
# set()
# sold[27] - sold[15]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[15] - sold[28]
# {'ListAgentEmail'}
# sold[28] - sold[15]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[16] - sold[17]
# set()
# sold[17] - sold[16]
# set()
# sold[16] - sold[18]
# set()
# sold[18] - sold[16]
# set()
# sold[16] - sold[19]
# set()
# sold[19] - sold[16]
# set()
# sold[16] - sold[20]
# set()
# sold[20] - sold[16]
# set()
# sold[16] - sold[21]
# set()
# sold[21] - sold[16]
# set()
# sold[16] - sold[22]
# set()
# sold[22] - sold[16]
# set()
# sold[16] - sold[23]
# set()
# sold[23] - sold[16]
# set()
# sold[16] - sold[24]
# set()
# sold[24] - sold[16]
# set()
# sold[16] - sold[25]
# set()
# sold[25] - sold[16]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[16] - sold[26]
# set()
# sold[26] - sold[16]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[16] - sold[27]
# set()
# sold[27] - sold[16]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[16] - sold[28]
# {'ListAgentEmail'}
# sold[28] - sold[16]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[17] - sold[18]
# set()
# sold[18] - sold[17]
# set()
# sold[17] - sold[19]
# set()
# sold[19] - sold[17]
# set()
# sold[17] - sold[20]
# set()
# sold[20] - sold[17]
# set()
# sold[17] - sold[21]
# set()
# sold[21] - sold[17]
# set()
# sold[17] - sold[22]
# set()
# sold[22] - sold[17]
# set()
# sold[17] - sold[23]
# set()
# sold[23] - sold[17]
# set()
# sold[17] - sold[24]
# set()
# sold[24] - sold[17]
# set()
# sold[17] - sold[25]
# set()
# sold[25] - sold[17]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[17] - sold[26]
# set()
# sold[26] - sold[17]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[17] - sold[27]
# set()
# sold[27] - sold[17]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[17] - sold[28]
# {'ListAgentEmail'}
# sold[28] - sold[17]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[18] - sold[19]
# set()
# sold[19] - sold[18]
# set()
# sold[18] - sold[20]
# set()
# sold[20] - sold[18]
# set()
# sold[18] - sold[21]
# set()
# sold[21] - sold[18]
# set()
# sold[18] - sold[22]
# set()
# sold[22] - sold[18]
# set()
# sold[18] - sold[23]
# set()
# sold[23] - sold[18]
# set()
# sold[18] - sold[24]
# set()
# sold[24] - sold[18]
# set()
# sold[18] - sold[25]
# set()
# sold[25] - sold[18]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[18] - sold[26]
# set()
# sold[26] - sold[18]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[18] - sold[27]
# set()
# sold[27] - sold[18]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[18] - sold[28]
# {'ListAgentEmail'}
# sold[28] - sold[18]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[19] - sold[20]
# set()
# sold[20] - sold[19]
# set()
# sold[19] - sold[21]
# set()
# sold[21] - sold[19]
# set()
# sold[19] - sold[22]
# set()
# sold[22] - sold[19]
# set()
# sold[19] - sold[23]
# set()
# sold[23] - sold[19]
# set()
# sold[19] - sold[24]
# set()
# sold[24] - sold[19]
# set()
# sold[19] - sold[25]
# set()
# sold[25] - sold[19]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[19] - sold[26]
# set()
# sold[26] - sold[19]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[19] - sold[27]
# set()
# sold[27] - sold[19]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[19] - sold[28]
# {'ListAgentEmail'}
# sold[28] - sold[19]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[20] - sold[21]
# set()
# sold[21] - sold[20]
# set()
# sold[20] - sold[22]
# set()
# sold[22] - sold[20]
# set()
# sold[20] - sold[23]
# set()
# sold[23] - sold[20]
# set()
# sold[20] - sold[24]
# set()
# sold[24] - sold[20]
# set()
# sold[20] - sold[25]
# set()
# sold[25] - sold[20]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[20] - sold[26]
# set()
# sold[26] - sold[20]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[20] - sold[27]
# set()
# sold[27] - sold[20]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[20] - sold[28]
# {'ListAgentEmail'}
# sold[28] - sold[20]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[21] - sold[22]
# set()
# sold[22] - sold[21]
# set()
# sold[21] - sold[23]
# set()
# sold[23] - sold[21]
# set()
# sold[21] - sold[24]
# set()
# sold[24] - sold[21]
# set()
# sold[21] - sold[25]
# set()
# sold[25] - sold[21]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[21] - sold[26]
# set()
# sold[26] - sold[21]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[21] - sold[27]
# set()
# sold[27] - sold[21]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[21] - sold[28]
# {'ListAgentEmail'}
# sold[28] - sold[21]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[22] - sold[23]
# set()
# sold[23] - sold[22]
# set()
# sold[22] - sold[24]
# set()
# sold[24] - sold[22]
# set()
# sold[22] - sold[25]
# set()
# sold[25] - sold[22]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[22] - sold[26]
# set()
# sold[26] - sold[22]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[22] - sold[27]
# set()
# sold[27] - sold[22]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[22] - sold[28]
# {'ListAgentEmail'}
# sold[28] - sold[22]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[23] - sold[24]
# set()
# sold[24] - sold[23]
# set()
# sold[23] - sold[25]
# set()
# sold[25] - sold[23]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[23] - sold[26]
# set()
# sold[26] - sold[23]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[23] - sold[27]
# set()
# sold[27] - sold[23]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[23] - sold[28]
# {'ListAgentEmail'}
# sold[28] - sold[23]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[24] - sold[25]
# set()
# sold[25] - sold[24]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[24] - sold[26]
# set()
# sold[26] - sold[24]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[24] - sold[27]
# set()
# sold[27] - sold[24]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[24] - sold[28]
# {'ListAgentEmail'}
# sold[28] - sold[24]
# {'OriginatingSystemSubName', 'OriginatingSystemName'}
# sold[25] - sold[26]
# set()
# sold[26] - sold[25]
# set()
# sold[25] - sold[27]
# set()
# sold[27] - sold[25]
# set()
# sold[25] - sold[28]
# {'ListAgentEmail'}
# sold[28] - sold[25]
# set()
# sold[26] - sold[27]
# set()
# sold[27] - sold[26]
# set()
# sold[26] - sold[28]
# {'ListAgentEmail'}
# sold[28] - sold[26]
# set()
# sold[27] - sold[28]
# {'ListAgentEmail'}
# sold[28] - sold[27]
# set()

# %%
df_sold = pd.concat(sold)

row_df_sold = df_sold.shape[0]

print(df_sold.shape)

df_sold.head()
# Out:
# (639916, 84)
#               BuyerAgentAOR              ListAgentAOR          Flooring  \
# 0               Mlslistings               Mlslistings  Carpet,Tile,Wood
# 1                HighDesert                HighDesert               NaN
# 2              OrangeCounty              OrangeCounty               NaN
# 3             InlandValleys             InlandValleys               NaN
# 4  SouthwestRiversideCounty  SouthwestRiversideCounty               NaN
#
#   ViewYN WaterfrontYN BasementYN PoolPrivateYN  OriginalListPrice  ListingKey  \
# 0   True          NaN        NaN         False           499000.0   551985747
# 1    NaN          NaN        NaN           NaN                0.0   535486633
# 2   True          NaN        NaN           NaN            75000.0   529986282
# 3   True          NaN        NaN           NaN           199000.0   529618166
# 4   True          NaN        NaN           NaN            19500.0   522614340
#
#                ListAgentEmail  ... PostalCode  AssociationFee  \
# 0       jwachter@cbnorcal.com  ...      94401          6472.0
# 1  eabrown@lee-associates.com  ...      92394             NaN
# 2             Joe@9WINWIN.com  ...      93240             NaN
# 3    carolthefinder@yahoo.com  ...      92308             NaN
# 4      jtavisola@tavisola.com  ...      93544             0.0
#
#   LotSizeSquareFeet MiddleOrJuniorSchoolDistrict  OriginatingSystemName  \
# 0               NaN                          NaN                  CRMLS
# 1           52320.0                          NaN                  CRMLS
# 2          217364.0                          NaN                  CRMLS
# 3          217800.0                          NaN                  CRMLS
# 4          108883.0                          NaN                  CRMLS
#
#    OriginatingSystemSubName BuyerAgencyCompensationType  \
# 0                CRMLS_MLSL                         NaN
# 1                 CRMLS_CRM                         NaN
# 2                 CRMLS_CRM                         NaN
# 3                 CRMLS_CRM                         NaN
# 4                 CRMLS_CRM                         NaN
#
#   BuyerAgencyCompensation  latfilled  lonfilled
# 0                     NaN        NaN        NaN
# 1                     NaN        NaN        NaN
# 2                     NaN        NaN        NaN
# 3                     NaN        NaN        NaN
# 4                     NaN        NaN        NaN
#
# [5 rows x 84 columns]

# %%
df_sold.columns
# Out:
# Index(['BuyerAgentAOR', 'ListAgentAOR', 'Flooring', 'ViewYN', 'WaterfrontYN',
#        'BasementYN', 'PoolPrivateYN', 'OriginalListPrice', 'ListingKey',
#        'ListAgentEmail', 'CloseDate', 'ClosePrice', 'ListAgentFirstName',
#        'ListAgentLastName', 'Latitude', 'Longitude', 'UnparsedAddress',
#        'PropertyType', 'LivingArea', 'ListPrice', 'DaysOnMarket',
#        'ListOfficeName', 'BuyerOfficeName', 'CoListOfficeName',
#        'ListAgentFullName', 'CoListAgentFirstName', 'CoListAgentLastName',
#        'BuyerAgentMlsId', 'BuyerAgentFirstName', 'BuyerAgentLastName',
#        'FireplacesTotal', 'AssociationFeeFrequency', 'AboveGradeFinishedArea',
#        'ListingKeyNumeric', 'MLSAreaMajor', 'TaxAnnualAmount',
#        'CountyOrParish', 'MlsStatus', 'ElementarySchool', 'AttachedGarageYN',
#        'ParkingTotal', 'BuilderName', 'PropertySubType', 'LotSizeAcres',
#        'SubdivisionName', 'BuyerOfficeAOR', 'YearBuilt', 'StreetNumberNumeric',
#        'ListingId', 'BathroomsTotalInteger', 'City', 'TaxYear',
#        'BuildingAreaTotal', 'BedroomsTotal', 'ContractStatusChangeDate',
#        'ElementarySchoolDistrict', 'CoBuyerAgentFirstName',
#        'PurchaseContractDate', 'ListingContractDate', 'BelowGradeFinishedArea',
#        'BusinessType', 'StateOrProvince', 'CoveredSpaces',
#        'MiddleOrJuniorSchool', 'FireplaceYN', 'Stories', 'HighSchool',
#        'Levels', 'LotSizeDimensions', 'LotSizeArea', 'MainLevelBedrooms',
#        'NewConstructionYN', 'GarageSpaces', 'HighSchoolDistrict', 'PostalCode',
#        'AssociationFee', 'LotSizeSquareFeet', 'MiddleOrJuniorSchoolDistrict',
#        'OriginatingSystemName', 'OriginatingSystemSubName',
#        'BuyerAgencyCompensationType', 'BuyerAgencyCompensation', 'latfilled',
#        'lonfilled'],
#       dtype='str')

# %% [markdown]
# The columns that are useful considering domain perspective of analyzing housing market following

# %%
keep_cols = [
    # IDs
    "ListingKey",
    "ListingKeyNumeric",
    "ListingId",

    # Dates
    "CloseDate",
    "ListingContractDate",
    "PurchaseContractDate",
    "ContractStatusChangeDate",

    # Price fields
    "ClosePrice",
    "ListPrice",
    "OriginalListPrice",

    # Property characteristics
    "PropertyType",
    "PropertySubType",
    "LivingArea",
    "BedroomsTotal",
    "BathroomsTotalInteger",
    "YearBuilt",
    "DaysOnMarket",
    "LotSizeSquareFeet",

    # Location
    "Latitude",
    "Longitude",
    "UnparsedAddress",
    "City",
    "CountyOrParish",
    "PostalCode",
    "StateOrProvince",
    "MLSAreaMajor",
    
    # School
    "ElementarySchool",
    "ElementarySchoolDistrict",
    "MiddleOrJuniorSchool",
    "MiddleOrJuniorSchoolDistrict",
    "HighSchool",
    "HighSchoolDistrict",

    # Agent / office competitive analysis
    "ListAgentFirstName",
    "ListAgentLastName",
    "ListAgentFullName",
    "ListOfficeName",
    "BuyerAgentFirstName",
    "BuyerAgentLastName",
    "BuyerOfficeName",

    # Useful property features
    "GarageSpaces",
    "ParkingTotal",
    "FireplacesTotal",
    "FireplaceYN",
    "PoolPrivateYN",
    "WaterfrontYN",
    "ViewYN",
    "AttachedGarageYN",
    "NewConstructionYN",
    "Levels",
    "Stories",
    "TaxAnnualAmount",
    "TaxYear",
    "Flooring",
    "BasementYN",

    # Status
    "MlsStatus",
    "BusinessType",

    #Additional information property builder and neighborhood, or community
    "BuilderName",
    "SubdivisionName"    
]

# %%
df_sold = df_sold.drop(
    columns=[
        # which data system is from
        'OriginatingSystemSubName', 
        'OriginatingSystemName', 


        # Agent extra information as redundent.
        # Already included agent and office names
        "BuyerAgentAOR",
        "ListAgentAOR",
        "BuyerOfficeAOR",
        "AssociationFeeFrequency",
        "AssociationFee",

        # personal contact
        "ListAgentEmail",

        # Redundent information of property features
        "LotSizeAcres",
        "LotSizeDimensions",
        "LotSizeArea",
        "BuildingAreaTotal",
        "AboveGradeFinishedArea",
        "BelowGradeFinishedArea",
        "MainLevelBedrooms",
        "lonfilled",
        "latfilled",
        "StreetNumberNumeric",
        "CoveredSpaces"
        ]
    )

df_sold.shape
# Out:
# (639916, 65)

# %%
# check the property type 
print("List of property types:")
print(df_sold["PropertyType"].unique())
print()
print("List of property types of residential:")
print(df_sold[df_sold["PropertyType"]=="Residential"]["PropertySubType"].unique())
# Out:
# List of property types:
# <StringArray>
# [        'Residential',     'CommercialLease',                'Land',
#     'ResidentialLease',  'ManufacturedInPark',   'ResidentialIncome',
#       'CommercialSale', 'BusinessOpportunity']
# Length: 8, dtype: str
#
# List of property types of residential:
# <StringArray>
# [          'Condominium', 'SingleFamilyResidence',                'Duplex',
#              'Townhouse',    'ManufacturedOnLand',             'Timeshare',
#                      nan,            'MobileHome',               'Triplex',
#       'StockCooperative',              'BoatSlip',              'MixedUse',
#                  'Cabin',                  'Farm',      'ManufacturedHome',
#             'Quadruplex',                  'Loft',            'OwnYourOwn',
#          'DeededParking',           'CoOwnership',                'Studio']
# Length: 21, dtype: str

# %% [markdown]
# Not all residential properties behave the same way in market. The	PropertyType
# and	PropertySubType	fields	in	the	MLS	distinguish	between	different	structures,	and	mixing	them
# in	an	analysis	without	filtering	can	produce	misleading	results.
#
# Our target is residential properties that we must filter it from **PropertyType**.

# %%
df_sold = df_sold[df_sold["PropertyType"] == "Residential"]

print("List of property types:")
print(df_sold["PropertyType"].unique())
# Out:
# List of property types:
# <StringArray>
# ['Residential']
# Length: 1, dtype: str

# %%
print(df_sold[df_sold.duplicated(keep=False)])
print("Total duplicate rows:", df_sold["ListingKey"].duplicated().sum())
# Out:
#       Flooring ViewYN WaterfrontYN BasementYN PoolPrivateYN  \
# 1909       NaN  False          NaN        NaN         False
# 1910       NaN  False          NaN        NaN         False
# 4737       NaN  False          NaN        NaN         False
# 4738       NaN  False          NaN        NaN         False
# 8234      Tile  False          NaN        NaN         False
# ...        ...    ...          ...        ...           ...
# 2913       NaN  False          NaN        NaN         False
# 15451      NaN  False          NaN        NaN         False
# 15452      NaN  False          NaN        NaN         False
# 17464      NaN  False          NaN        NaN         False
# 17465      NaN  False          NaN        NaN         False
#
#        OriginalListPrice  ListingKey   CloseDate  ClosePrice  \
# 1909           1299000.0  1079063603  2024-08-16   1269000.0
# 1910           1299000.0  1079063603  2024-08-16   1269000.0
# 4737           2000000.0  1077699506  2024-08-08   2000000.0
# 4738           2000000.0  1077699506  2024-08-08   2000000.0
# 8234           1195000.0  1077313817  2024-08-12   1224000.0
# ...                  ...         ...         ...         ...
# 2913           1099900.0  1119947269  2025-08-26   1100000.0
# 15451          3250000.0  1114799272  2025-08-08   2500000.0
# 15452          3250000.0  1114799272  2025-08-08   2500000.0
# 17464          1795000.0  1114185301  2025-08-29   1607300.0
# 17465          1795000.0  1114185301  2025-08-29   1607300.0
#
#       ListAgentFirstName  ...  HighSchool   Levels  NewConstructionYN  \
# 1909                 Hui  ...         NaN      One               True
# 1910                 Hui  ...         NaN      One               True
# 4737            Michelle  ...         NaN  One,Two               True
# 4738            Michelle  ...         NaN  One,Two               True
# 8234              Kenzie  ...         NaN      One              False
# ...                  ...  ...         ...      ...                ...
# 2913                Gary  ...         NaN      One              False
# 15451               Sean  ...  Huntington      One              False
# 15452               Sean  ...  Huntington      One              False
# 17464              Kevin  ...         NaN      One              False
# 17465              Kevin  ...         NaN      One              False
#
#       GarageSpaces           HighSchoolDistrict  PostalCode  \
# 1909           0.0           Los Nietos Unified       90606
# 1910           0.0           Los Nietos Unified       90606
# 4737           0.0           Bellflower Unified       90712
# 4738           0.0           Bellflower Unified       90712
# 8234           3.0             Pasadena Unified       91107
# ...            ...                          ...         ...
# 2913           0.0                          NaN       92113
# 15451          4.0  Huntington Beach Union High       92648
# 15452          4.0  Huntington Beach Union High       92648
# 17464          2.0                          NaN       92116
# 17465          2.0                          NaN       92116
#
#        LotSizeSquareFeet  MiddleOrJuniorSchoolDistrict  \
# 1909              6380.0                           NaN
# 1910              6380.0                           NaN
# 4737              5376.0                           NaN
# 4738              5376.0                           NaN
# 8234              8575.0                           NaN
# ...                  ...                           ...
# 2913                 NaN                           NaN
# 15451             5663.0                           NaN
# 15452             5663.0                           NaN
# 17464                NaN                           NaN
# 17465                NaN                           NaN
#
#       BuyerAgencyCompensationType BuyerAgencyCompensation
# 1909                          NaN                     NaN
# 1910                          NaN                     NaN
# 4737                          NaN                     NaN
# 4738                          NaN                     NaN
# 8234                          NaN                     NaN
# ...                           ...                     ...
# 2913                          NaN                     NaN
# 15451                         NaN                     NaN
# 15452                         NaN                     NaN
# 17464                         NaN                     NaN
# 17465                         NaN                     NaN
#
# [96 rows x 65 columns]
# Total duplicate rows: 370

# %% [markdown]
# There are extra duplicate properties of 594 in sold dataset. We will drop those duplicates and keep the lastest properties considering the date time order.

# %%
temp_close_date = pd.to_datetime(df_sold["CloseDate"], errors="coerce")
bad_dates = df_sold[
    df_sold["CloseDate"].notna() & temp_close_date.isna()
]

print(bad_dates[["ListingKey", "CloseDate"]])
print("Number of unreadable CloseDate values:", bad_dates.shape[0])
# Out:
# Empty DataFrame
# Columns: [ListingKey, CloseDate]
# Index: []
# Number of unreadable CloseDate values: 0

# %%
before_properties = df_sold.shape[0]

df_sold["CloseDate"] = pd.to_datetime(df_sold["CloseDate"], errors = "coerce")

df_sold = (
    df_sold
    .sort_values("CloseDate")
    .drop_duplicates(subset = ["ListingKey"], keep="last")
    .reset_index(drop=True)
)
print("Number of dropped duplicate properties:", before_properties - df_sold.shape[0])
print("Remaining duplicated ListingKeys:", df_sold["ListingKey"].duplicated().sum())
# Out:
# Number of dropped duplicate properties: 370
# Remaining duplicated ListingKeys: 0

# %%
listing0 = pd.read_csv("CRMLSListing202401.csv")
listing1 = pd.read_csv("CRMLSListing202402.csv")
listing2 = pd.read_csv("CRMLSListing202403.csv")
listing3 = pd.read_csv("CRMLSListing202404.csv")
listing4 = pd.read_csv("CRMLSListing202405.csv")
listing5 = pd.read_csv("CRMLSListing202406.csv")
listing6 = pd.read_csv("CRMLSListing202407.csv")
listing7 = pd.read_csv("CRMLSListing202408.csv")
listing8 = pd.read_csv("CRMLSListing202409.csv")
listing9 = pd.read_csv("CRMLSListing202410.csv")
listing10 = pd.read_csv("CRMLSListing202411.csv")
listing11 = pd.read_csv("CRMLSListing202412.csv")
listing12 = pd.read_csv("CRMLSListing202501.csv")
listing13 = pd.read_csv("CRMLSListing202502.csv")
listing14 = pd.read_csv("CRMLSListing202503.csv")
listing15 = pd.read_csv("CRMLSListing202504.csv")
listing16 = pd.read_csv("CRMLSListing202505.csv")
listing17 = pd.read_csv("CRMLSListing202506.csv")
listing18 = pd.read_csv("CRMLSListing202507.csv")
listing19 = pd.read_csv("CRMLSListing202508.csv")
listing20 = pd.read_csv("CRMLSListing202509.csv")
listing21 = pd.read_csv("CRMLSListing202510.csv")
listing22 = pd.read_csv("CRMLSListing202511.csv")
listing23 = pd.read_csv("CRMLSListing202512.csv")
listing24 = pd.read_csv("CRMLSListing202601.csv")
listing25 = pd.read_csv("CRMLSListing202602.csv")
listing26 = pd.read_csv("CRMLSListing202603.csv")
listing27 = pd.read_csv("CRMLSListing202604.csv")
listing28 = pd.read_csv("CRMLSListing202605.csv")
# Out:
# C:\Users\junki\AppData\Local\Temp\ipykernel_9880\4050626818.py:26: DtypeWarning: Columns (0: ElementarySchool, 1: BusinessType, 2: MiddleOrJuniorSchool, 3: HighSchool) have mixed types. Specify dtype option on import or set low_memory=False.
#   listing25 = pd.read_csv("CRMLSListing202602.csv")

# %%
print(listing0.shape)
print(listing1.shape)
print(listing2.shape)
print(listing3.shape)
print(listing4.shape)
print(listing5.shape)
print(listing6.shape)
print(listing7.shape)
print(listing8.shape)
print(listing9.shape)
print(listing10.shape)
print(listing11.shape)
print(listing12.shape)
print(listing13.shape)
print(listing14.shape)
print(listing15.shape)
print(listing16.shape)
print(listing17.shape)
print(listing18.shape)
print(listing19.shape)
print(listing20.shape)
print(listing21.shape)
print(listing22.shape)
print(listing23.shape)
print(listing24.shape)
print(listing25.shape)
print(listing26.shape)
print(listing27.shape)
print(listing28.shape)
# Out:
# (27454, 84)
# (27447, 84)
# (32282, 84)
# (36503, 84)
# (38796, 82)
# (35893, 82)
# (36340, 82)
# (35305, 82)
# (34625, 82)
# (34730, 82)
# (25128, 82)
# (19417, 82)
# (37469, 82)
# (33983, 82)
# (38492, 82)
# (40187, 82)
# (40271, 82)
# (26399, 82)
# (27345, 82)
# (25210, 82)
# (26923, 82)
# (27586, 82)
# (20677, 82)
# (18773, 82)
# (2606, 82)
# (32884, 82)
# (39153, 82)
# (39020, 82)
# (36201, 81)

# %%
listings = [
    listing0, listing1, listing2, listing3, listing4, listing5, listing6,
    listing7, listing8, listing9, listing10, listing11, listing12,
    listing13, listing14, listing15, listing16, listing17, listing18,
    listing19, listing20, listing21, listing22, listing23, listing24,
    listing25, listing26, listing27, listing28
]

for i in range(len(listings)):
    for j in range(i + 1, len(listings)):
        print(f"listing[{i}] - listing[{j}]")
        print(set(listings[i].columns) - set(listings[j].columns))

        print(f"listing[{j}] - listing[{i}]")
        print(set(listings[j].columns) - set(listings[i].columns))
# Out:
# listing[0] - listing[1]
# set()
# listing[1] - listing[0]
# set()
# listing[0] - listing[2]
# set()
# listing[2] - listing[0]
# set()
# listing[0] - listing[3]
# set()
# listing[3] - listing[0]
# set()
# listing[0] - listing[4]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[4] - listing[0]
# set()
# listing[0] - listing[5]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[5] - listing[0]
# set()
# listing[0] - listing[6]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[6] - listing[0]
# set()
# listing[0] - listing[7]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[7] - listing[0]
# set()
# listing[0] - listing[8]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[8] - listing[0]
# set()
# listing[0] - listing[9]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[9] - listing[0]
# set()
# listing[0] - listing[10]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[10] - listing[0]
# set()
# listing[0] - listing[11]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[11] - listing[0]
# set()
# listing[0] - listing[12]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[12] - listing[0]
# set()
# listing[0] - listing[13]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[13] - listing[0]
# set()
# listing[0] - listing[14]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[14] - listing[0]
# set()
# listing[0] - listing[15]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[15] - listing[0]
# set()
# listing[0] - listing[16]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[16] - listing[0]
# set()
# listing[0] - listing[17]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[17] - listing[0]
# set()
# listing[0] - listing[18]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[18] - listing[0]
# set()
# listing[0] - listing[19]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[19] - listing[0]
# set()
# listing[0] - listing[20]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[20] - listing[0]
# set()
# listing[0] - listing[21]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[21] - listing[0]
# set()
# listing[0] - listing[22]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[22] - listing[0]
# set()
# listing[0] - listing[23]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[23] - listing[0]
# set()
# listing[0] - listing[24]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[24] - listing[0]
# set()
# listing[0] - listing[25]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[25] - listing[0]
# set()
# listing[0] - listing[26]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[26] - listing[0]
# set()
# listing[0] - listing[27]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[27] - listing[0]
# set()
# listing[0] - listing[28]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation', 'ListAgentEmail'}
# listing[28] - listing[0]
# set()
# listing[1] - listing[2]
# set()
# listing[2] - listing[1]
# set()
# listing[1] - listing[3]
# set()
# listing[3] - listing[1]
# set()
# listing[1] - listing[4]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[4] - listing[1]
# set()
# listing[1] - listing[5]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[5] - listing[1]
# set()
# listing[1] - listing[6]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[6] - listing[1]
# set()
# listing[1] - listing[7]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[7] - listing[1]
# set()
# listing[1] - listing[8]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[8] - listing[1]
# set()
# listing[1] - listing[9]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[9] - listing[1]
# set()
# listing[1] - listing[10]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[10] - listing[1]
# set()
# listing[1] - listing[11]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[11] - listing[1]
# set()
# listing[1] - listing[12]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[12] - listing[1]
# set()
# listing[1] - listing[13]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[13] - listing[1]
# set()
# listing[1] - listing[14]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[14] - listing[1]
# set()
# listing[1] - listing[15]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[15] - listing[1]
# set()
# listing[1] - listing[16]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[16] - listing[1]
# set()
# listing[1] - listing[17]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[17] - listing[1]
# set()
# listing[1] - listing[18]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[18] - listing[1]
# set()
# listing[1] - listing[19]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[19] - listing[1]
# set()
# listing[1] - listing[20]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[20] - listing[1]
# set()
# listing[1] - listing[21]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[21] - listing[1]
# set()
# listing[1] - listing[22]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[22] - listing[1]
# set()
# listing[1] - listing[23]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[23] - listing[1]
# set()
# listing[1] - listing[24]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[24] - listing[1]
# set()
# listing[1] - listing[25]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[25] - listing[1]
# set()
# listing[1] - listing[26]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[26] - listing[1]
# set()
# listing[1] - listing[27]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[27] - listing[1]
# set()
# listing[1] - listing[28]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation', 'ListAgentEmail'}
# listing[28] - listing[1]
# set()
# listing[2] - listing[3]
# set()
# listing[3] - listing[2]
# set()
# listing[2] - listing[4]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[4] - listing[2]
# set()
# listing[2] - listing[5]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[5] - listing[2]
# set()
# listing[2] - listing[6]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[6] - listing[2]
# set()
# listing[2] - listing[7]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[7] - listing[2]
# set()
# listing[2] - listing[8]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[8] - listing[2]
# set()
# listing[2] - listing[9]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[9] - listing[2]
# set()
# listing[2] - listing[10]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[10] - listing[2]
# set()
# listing[2] - listing[11]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[11] - listing[2]
# set()
# listing[2] - listing[12]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[12] - listing[2]
# set()
# listing[2] - listing[13]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[13] - listing[2]
# set()
# listing[2] - listing[14]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[14] - listing[2]
# set()
# listing[2] - listing[15]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[15] - listing[2]
# set()
# listing[2] - listing[16]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[16] - listing[2]
# set()
# listing[2] - listing[17]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[17] - listing[2]
# set()
# listing[2] - listing[18]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[18] - listing[2]
# set()
# listing[2] - listing[19]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[19] - listing[2]
# set()
# listing[2] - listing[20]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[20] - listing[2]
# set()
# listing[2] - listing[21]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[21] - listing[2]
# set()
# listing[2] - listing[22]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[22] - listing[2]
# set()
# listing[2] - listing[23]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[23] - listing[2]
# set()
# listing[2] - listing[24]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[24] - listing[2]
# set()
# listing[2] - listing[25]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[25] - listing[2]
# set()
# listing[2] - listing[26]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[26] - listing[2]
# set()
# listing[2] - listing[27]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[27] - listing[2]
# set()
# listing[2] - listing[28]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation', 'ListAgentEmail'}
# listing[28] - listing[2]
# set()
# listing[3] - listing[4]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[4] - listing[3]
# set()
# listing[3] - listing[5]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[5] - listing[3]
# set()
# listing[3] - listing[6]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[6] - listing[3]
# set()
# listing[3] - listing[7]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[7] - listing[3]
# set()
# listing[3] - listing[8]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[8] - listing[3]
# set()
# listing[3] - listing[9]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[9] - listing[3]
# set()
# listing[3] - listing[10]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[10] - listing[3]
# set()
# listing[3] - listing[11]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[11] - listing[3]
# set()
# listing[3] - listing[12]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[12] - listing[3]
# set()
# listing[3] - listing[13]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[13] - listing[3]
# set()
# listing[3] - listing[14]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[14] - listing[3]
# set()
# listing[3] - listing[15]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[15] - listing[3]
# set()
# listing[3] - listing[16]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[16] - listing[3]
# set()
# listing[3] - listing[17]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[17] - listing[3]
# set()
# listing[3] - listing[18]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[18] - listing[3]
# set()
# listing[3] - listing[19]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[19] - listing[3]
# set()
# listing[3] - listing[20]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[20] - listing[3]
# set()
# listing[3] - listing[21]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[21] - listing[3]
# set()
# listing[3] - listing[22]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[22] - listing[3]
# set()
# listing[3] - listing[23]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[23] - listing[3]
# set()
# listing[3] - listing[24]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[24] - listing[3]
# set()
# listing[3] - listing[25]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[25] - listing[3]
# set()
# listing[3] - listing[26]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[26] - listing[3]
# set()
# listing[3] - listing[27]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation'}
# listing[27] - listing[3]
# set()
# listing[3] - listing[28]
# {'BuyerAgencyCompensationType', 'BuyerAgencyCompensation', 'ListAgentEmail'}
# listing[28] - listing[3]
# set()
# listing[4] - listing[5]
# set()
# listing[5] - listing[4]
# set()
# listing[4] - listing[6]
# set()
# listing[6] - listing[4]
# set()
# listing[4] - listing[7]
# set()
# listing[7] - listing[4]
# set()
# listing[4] - listing[8]
# set()
# listing[8] - listing[4]
# set()
# listing[4] - listing[9]
# set()
# listing[9] - listing[4]
# set()
# listing[4] - listing[10]
# set()
# listing[10] - listing[4]
# set()
# listing[4] - listing[11]
# set()
# listing[11] - listing[4]
# set()
# listing[4] - listing[12]
# set()
# listing[12] - listing[4]
# set()
# listing[4] - listing[13]
# set()
# listing[13] - listing[4]
# set()
# listing[4] - listing[14]
# set()
# listing[14] - listing[4]
# set()
# listing[4] - listing[15]
# set()
# listing[15] - listing[4]
# set()
# listing[4] - listing[16]
# set()
# listing[16] - listing[4]
# set()
# listing[4] - listing[17]
# set()
# listing[17] - listing[4]
# set()
# listing[4] - listing[18]
# set()
# listing[18] - listing[4]
# set()
# listing[4] - listing[19]
# set()
# listing[19] - listing[4]
# set()
# listing[4] - listing[20]
# set()
# listing[20] - listing[4]
# set()
# listing[4] - listing[21]
# set()
# listing[21] - listing[4]
# set()
# listing[4] - listing[22]
# set()
# listing[22] - listing[4]
# set()
# listing[4] - listing[23]
# set()
# listing[23] - listing[4]
# set()
# listing[4] - listing[24]
# set()
# listing[24] - listing[4]
# set()
# listing[4] - listing[25]
# set()
# listing[25] - listing[4]
# set()
# listing[4] - listing[26]
# set()
# listing[26] - listing[4]
# set()
# listing[4] - listing[27]
# set()
# listing[27] - listing[4]
# set()
# listing[4] - listing[28]
# {'ListAgentEmail'}
# listing[28] - listing[4]
# set()
# listing[5] - listing[6]
# set()
# listing[6] - listing[5]
# set()
# listing[5] - listing[7]
# set()
# listing[7] - listing[5]
# set()
# listing[5] - listing[8]
# set()
# listing[8] - listing[5]
# set()
# listing[5] - listing[9]
# set()
# listing[9] - listing[5]
# set()
# listing[5] - listing[10]
# set()
# listing[10] - listing[5]
# set()
# listing[5] - listing[11]
# set()
# listing[11] - listing[5]
# set()
# listing[5] - listing[12]
# set()
# listing[12] - listing[5]
# set()
# listing[5] - listing[13]
# set()
# listing[13] - listing[5]
# set()
# listing[5] - listing[14]
# set()
# listing[14] - listing[5]
# set()
# listing[5] - listing[15]
# set()
# listing[15] - listing[5]
# set()
# listing[5] - listing[16]
# set()
# listing[16] - listing[5]
# set()
# listing[5] - listing[17]
# set()
# listing[17] - listing[5]
# set()
# listing[5] - listing[18]
# set()
# listing[18] - listing[5]
# set()
# listing[5] - listing[19]
# set()
# listing[19] - listing[5]
# set()
# listing[5] - listing[20]
# set()
# listing[20] - listing[5]
# set()
# listing[5] - listing[21]
# set()
# listing[21] - listing[5]
# set()
# listing[5] - listing[22]
# set()
# listing[22] - listing[5]
# set()
# listing[5] - listing[23]
# set()
# listing[23] - listing[5]
# set()
# listing[5] - listing[24]
# set()
# listing[24] - listing[5]
# set()
# listing[5] - listing[25]
# set()
# listing[25] - listing[5]
# set()
# listing[5] - listing[26]
# set()
# listing[26] - listing[5]
# set()
# listing[5] - listing[27]
# set()
# listing[27] - listing[5]
# set()
# listing[5] - listing[28]
# {'ListAgentEmail'}
# listing[28] - listing[5]
# set()
# listing[6] - listing[7]
# set()
# listing[7] - listing[6]
# set()
# listing[6] - listing[8]
# set()
# listing[8] - listing[6]
# set()
# listing[6] - listing[9]
# set()
# listing[9] - listing[6]
# set()
# listing[6] - listing[10]
# set()
# listing[10] - listing[6]
# set()
# listing[6] - listing[11]
# set()
# listing[11] - listing[6]
# set()
# listing[6] - listing[12]
# set()
# listing[12] - listing[6]
# set()
# listing[6] - listing[13]
# set()
# listing[13] - listing[6]
# set()
# listing[6] - listing[14]
# set()
# listing[14] - listing[6]
# set()
# listing[6] - listing[15]
# set()
# listing[15] - listing[6]
# set()
# listing[6] - listing[16]
# set()
# listing[16] - listing[6]
# set()
# listing[6] - listing[17]
# set()
# listing[17] - listing[6]
# set()
# listing[6] - listing[18]
# set()
# listing[18] - listing[6]
# set()
# listing[6] - listing[19]
# set()
# listing[19] - listing[6]
# set()
# listing[6] - listing[20]
# set()
# listing[20] - listing[6]
# set()
# listing[6] - listing[21]
# set()
# listing[21] - listing[6]
# set()
# listing[6] - listing[22]
# set()
# listing[22] - listing[6]
# set()
# listing[6] - listing[23]
# set()
# listing[23] - listing[6]
# set()
# listing[6] - listing[24]
# set()
# listing[24] - listing[6]
# set()
# listing[6] - listing[25]
# set()
# listing[25] - listing[6]
# set()
# listing[6] - listing[26]
# set()
# listing[26] - listing[6]
# set()
# listing[6] - listing[27]
# set()
# listing[27] - listing[6]
# set()
# listing[6] - listing[28]
# {'ListAgentEmail'}
# listing[28] - listing[6]
# set()
# listing[7] - listing[8]
# set()
# listing[8] - listing[7]
# set()
# listing[7] - listing[9]
# set()
# listing[9] - listing[7]
# set()
# listing[7] - listing[10]
# set()
# listing[10] - listing[7]
# set()
# listing[7] - listing[11]
# set()
# listing[11] - listing[7]
# set()
# listing[7] - listing[12]
# set()
# listing[12] - listing[7]
# set()
# listing[7] - listing[13]
# set()
# listing[13] - listing[7]
# set()
# listing[7] - listing[14]
# set()
# listing[14] - listing[7]
# set()
# listing[7] - listing[15]
# set()
# listing[15] - listing[7]
# set()
# listing[7] - listing[16]
# set()
# listing[16] - listing[7]
# set()
# listing[7] - listing[17]
# set()
# listing[17] - listing[7]
# set()
# listing[7] - listing[18]
# set()
# listing[18] - listing[7]
# set()
# listing[7] - listing[19]
# set()
# listing[19] - listing[7]
# set()
# listing[7] - listing[20]
# set()
# listing[20] - listing[7]
# set()
# listing[7] - listing[21]
# set()
# listing[21] - listing[7]
# set()
# listing[7] - listing[22]
# set()
# listing[22] - listing[7]
# set()
# listing[7] - listing[23]
# set()
# listing[23] - listing[7]
# set()
# listing[7] - listing[24]
# set()
# listing[24] - listing[7]
# set()
# listing[7] - listing[25]
# set()
# listing[25] - listing[7]
# set()
# listing[7] - listing[26]
# set()
# listing[26] - listing[7]
# set()
# listing[7] - listing[27]
# set()
# listing[27] - listing[7]
# set()
# listing[7] - listing[28]
# {'ListAgentEmail'}
# listing[28] - listing[7]
# set()
# listing[8] - listing[9]
# set()
# listing[9] - listing[8]
# set()
# listing[8] - listing[10]
# set()
# listing[10] - listing[8]
# set()
# listing[8] - listing[11]
# set()
# listing[11] - listing[8]
# set()
# listing[8] - listing[12]
# set()
# listing[12] - listing[8]
# set()
# listing[8] - listing[13]
# set()
# listing[13] - listing[8]
# set()
# listing[8] - listing[14]
# set()
# listing[14] - listing[8]
# set()
# listing[8] - listing[15]
# set()
# listing[15] - listing[8]
# set()
# listing[8] - listing[16]
# set()
# listing[16] - listing[8]
# set()
# listing[8] - listing[17]
# set()
# listing[17] - listing[8]
# set()
# listing[8] - listing[18]
# set()
# listing[18] - listing[8]
# set()
# listing[8] - listing[19]
# set()
# listing[19] - listing[8]
# set()
# listing[8] - listing[20]
# set()
# listing[20] - listing[8]
# set()
# listing[8] - listing[21]
# set()
# listing[21] - listing[8]
# set()
# listing[8] - listing[22]
# set()
# listing[22] - listing[8]
# set()
# listing[8] - listing[23]
# set()
# listing[23] - listing[8]
# set()
# listing[8] - listing[24]
# set()
# listing[24] - listing[8]
# set()
# listing[8] - listing[25]
# set()
# listing[25] - listing[8]
# set()
# listing[8] - listing[26]
# set()
# listing[26] - listing[8]
# set()
# listing[8] - listing[27]
# set()
# listing[27] - listing[8]
# set()
# listing[8] - listing[28]
# {'ListAgentEmail'}
# listing[28] - listing[8]
# set()
# listing[9] - listing[10]
# set()
# listing[10] - listing[9]
# set()
# listing[9] - listing[11]
# set()
# listing[11] - listing[9]
# set()
# listing[9] - listing[12]
# set()
# listing[12] - listing[9]
# set()
# listing[9] - listing[13]
# set()
# listing[13] - listing[9]
# set()
# listing[9] - listing[14]
# set()
# listing[14] - listing[9]
# set()
# listing[9] - listing[15]
# set()
# listing[15] - listing[9]
# set()
# listing[9] - listing[16]
# set()
# listing[16] - listing[9]
# set()
# listing[9] - listing[17]
# set()
# listing[17] - listing[9]
# set()
# listing[9] - listing[18]
# set()
# listing[18] - listing[9]
# set()
# listing[9] - listing[19]
# set()
# listing[19] - listing[9]
# set()
# listing[9] - listing[20]
# set()
# listing[20] - listing[9]
# set()
# listing[9] - listing[21]
# set()
# listing[21] - listing[9]
# set()
# listing[9] - listing[22]
# set()
# listing[22] - listing[9]
# set()
# listing[9] - listing[23]
# set()
# listing[23] - listing[9]
# set()
# listing[9] - listing[24]
# set()
# listing[24] - listing[9]
# set()
# listing[9] - listing[25]
# set()
# listing[25] - listing[9]
# set()
# listing[9] - listing[26]
# set()
# listing[26] - listing[9]
# set()
# listing[9] - listing[27]
# set()
# listing[27] - listing[9]
# set()
# listing[9] - listing[28]
# {'ListAgentEmail'}
# listing[28] - listing[9]
# set()
# listing[10] - listing[11]
# set()
# listing[11] - listing[10]
# set()
# listing[10] - listing[12]
# set()
# listing[12] - listing[10]
# set()
# listing[10] - listing[13]
# set()
# listing[13] - listing[10]
# set()
# listing[10] - listing[14]
# set()
# listing[14] - listing[10]
# set()
# listing[10] - listing[15]
# set()
# listing[15] - listing[10]
# set()
# listing[10] - listing[16]
# set()
# listing[16] - listing[10]
# set()
# listing[10] - listing[17]
# set()
# listing[17] - listing[10]
# set()
# listing[10] - listing[18]
# set()
# listing[18] - listing[10]
# set()
# listing[10] - listing[19]
# set()
# listing[19] - listing[10]
# set()
# listing[10] - listing[20]
# set()
# listing[20] - listing[10]
# set()
# listing[10] - listing[21]
# set()
# listing[21] - listing[10]
# set()
# listing[10] - listing[22]
# set()
# listing[22] - listing[10]
# set()
# listing[10] - listing[23]
# set()
# listing[23] - listing[10]
# set()
# listing[10] - listing[24]
# set()
# listing[24] - listing[10]
# set()
# listing[10] - listing[25]
# set()
# listing[25] - listing[10]
# set()
# listing[10] - listing[26]
# set()
# listing[26] - listing[10]
# set()
# listing[10] - listing[27]
# set()
# listing[27] - listing[10]
# set()
# listing[10] - listing[28]
# {'ListAgentEmail'}
# listing[28] - listing[10]
# set()
# listing[11] - listing[12]
# set()
# listing[12] - listing[11]
# set()
# listing[11] - listing[13]
# set()
# listing[13] - listing[11]
# set()
# listing[11] - listing[14]
# set()
# listing[14] - listing[11]
# set()
# listing[11] - listing[15]
# set()
# listing[15] - listing[11]
# set()
# listing[11] - listing[16]
# set()
# listing[16] - listing[11]
# set()
# listing[11] - listing[17]
# set()
# listing[17] - listing[11]
# set()
# listing[11] - listing[18]
# set()
# listing[18] - listing[11]
# set()
# listing[11] - listing[19]
# set()
# listing[19] - listing[11]
# set()
# listing[11] - listing[20]
# set()
# listing[20] - listing[11]
# set()
# listing[11] - listing[21]
# set()
# listing[21] - listing[11]
# set()
# listing[11] - listing[22]
# set()
# listing[22] - listing[11]
# set()
# listing[11] - listing[23]
# set()
# listing[23] - listing[11]
# set()
# listing[11] - listing[24]
# set()
# listing[24] - listing[11]
# set()
# listing[11] - listing[25]
# set()
# listing[25] - listing[11]
# set()
# listing[11] - listing[26]
# set()
# listing[26] - listing[11]
# set()
# listing[11] - listing[27]
# set()
# listing[27] - listing[11]
# set()
# listing[11] - listing[28]
# {'ListAgentEmail'}
# listing[28] - listing[11]
# set()
# listing[12] - listing[13]
# set()
# listing[13] - listing[12]
# set()
# listing[12] - listing[14]
# set()
# listing[14] - listing[12]
# set()
# listing[12] - listing[15]
# set()
# listing[15] - listing[12]
# set()
# listing[12] - listing[16]
# set()
# listing[16] - listing[12]
# set()
# listing[12] - listing[17]
# set()
# listing[17] - listing[12]
# set()
# listing[12] - listing[18]
# set()
# listing[18] - listing[12]
# set()
# listing[12] - listing[19]
# set()
# listing[19] - listing[12]
# set()
# listing[12] - listing[20]
# set()
# listing[20] - listing[12]
# set()
# listing[12] - listing[21]
# set()
# listing[21] - listing[12]
# set()
# listing[12] - listing[22]
# set()
# listing[22] - listing[12]
# set()
# listing[12] - listing[23]
# set()
# listing[23] - listing[12]
# set()
# listing[12] - listing[24]
# set()
# listing[24] - listing[12]
# set()
# listing[12] - listing[25]
# set()
# listing[25] - listing[12]
# set()
# listing[12] - listing[26]
# set()
# listing[26] - listing[12]
# set()
# listing[12] - listing[27]
# set()
# listing[27] - listing[12]
# set()
# listing[12] - listing[28]
# {'ListAgentEmail'}
# listing[28] - listing[12]
# set()
# listing[13] - listing[14]
# set()
# listing[14] - listing[13]
# set()
# listing[13] - listing[15]
# set()
# listing[15] - listing[13]
# set()
# listing[13] - listing[16]
# set()
# listing[16] - listing[13]
# set()
# listing[13] - listing[17]
# set()
# listing[17] - listing[13]
# set()
# listing[13] - listing[18]
# set()
# listing[18] - listing[13]
# set()
# listing[13] - listing[19]
# set()
# listing[19] - listing[13]
# set()
# listing[13] - listing[20]
# set()
# listing[20] - listing[13]
# set()
# listing[13] - listing[21]
# set()
# listing[21] - listing[13]
# set()
# listing[13] - listing[22]
# set()
# listing[22] - listing[13]
# set()
# listing[13] - listing[23]
# set()
# listing[23] - listing[13]
# set()
# listing[13] - listing[24]
# set()
# listing[24] - listing[13]
# set()
# listing[13] - listing[25]
# set()
# listing[25] - listing[13]
# set()
# listing[13] - listing[26]
# set()
# listing[26] - listing[13]
# set()
# listing[13] - listing[27]
# set()
# listing[27] - listing[13]
# set()
# listing[13] - listing[28]
# {'ListAgentEmail'}
# listing[28] - listing[13]
# set()
# listing[14] - listing[15]
# set()
# listing[15] - listing[14]
# set()
# listing[14] - listing[16]
# set()
# listing[16] - listing[14]
# set()
# listing[14] - listing[17]
# set()
# listing[17] - listing[14]
# set()
# listing[14] - listing[18]
# set()
# listing[18] - listing[14]
# set()
# listing[14] - listing[19]
# set()
# listing[19] - listing[14]
# set()
# listing[14] - listing[20]
# set()
# listing[20] - listing[14]
# set()
# listing[14] - listing[21]
# set()
# listing[21] - listing[14]
# set()
# listing[14] - listing[22]
# set()
# listing[22] - listing[14]
# set()
# listing[14] - listing[23]
# set()
# listing[23] - listing[14]
# set()
# listing[14] - listing[24]
# set()
# listing[24] - listing[14]
# set()
# listing[14] - listing[25]
# set()
# listing[25] - listing[14]
# set()
# listing[14] - listing[26]
# set()
# listing[26] - listing[14]
# set()
# listing[14] - listing[27]
# set()
# listing[27] - listing[14]
# set()
# listing[14] - listing[28]
# {'ListAgentEmail'}
# listing[28] - listing[14]
# set()
# listing[15] - listing[16]
# set()
# listing[16] - listing[15]
# set()
# listing[15] - listing[17]
# set()
# listing[17] - listing[15]
# set()
# listing[15] - listing[18]
# set()
# listing[18] - listing[15]
# set()
# listing[15] - listing[19]
# set()
# listing[19] - listing[15]
# set()
# listing[15] - listing[20]
# set()
# listing[20] - listing[15]
# set()
# listing[15] - listing[21]
# set()
# listing[21] - listing[15]
# set()
# listing[15] - listing[22]
# set()
# listing[22] - listing[15]
# set()
# listing[15] - listing[23]
# set()
# listing[23] - listing[15]
# set()
# listing[15] - listing[24]
# set()
# listing[24] - listing[15]
# set()
# listing[15] - listing[25]
# set()
# listing[25] - listing[15]
# set()
# listing[15] - listing[26]
# set()
# listing[26] - listing[15]
# set()
# listing[15] - listing[27]
# set()
# listing[27] - listing[15]
# set()
# listing[15] - listing[28]
# {'ListAgentEmail'}
# listing[28] - listing[15]
# set()
# listing[16] - listing[17]
# set()
# listing[17] - listing[16]
# set()
# listing[16] - listing[18]
# set()
# listing[18] - listing[16]
# set()
# listing[16] - listing[19]
# set()
# listing[19] - listing[16]
# set()
# listing[16] - listing[20]
# set()
# listing[20] - listing[16]
# set()
# listing[16] - listing[21]
# set()
# listing[21] - listing[16]
# set()
# listing[16] - listing[22]
# set()
# listing[22] - listing[16]
# set()
# listing[16] - listing[23]
# set()
# listing[23] - listing[16]
# set()
# listing[16] - listing[24]
# set()
# listing[24] - listing[16]
# set()
# listing[16] - listing[25]
# set()
# listing[25] - listing[16]
# set()
# listing[16] - listing[26]
# set()
# listing[26] - listing[16]
# set()
# listing[16] - listing[27]
# set()
# listing[27] - listing[16]
# set()
# listing[16] - listing[28]
# {'ListAgentEmail'}
# listing[28] - listing[16]
# set()
# listing[17] - listing[18]
# set()
# listing[18] - listing[17]
# set()
# listing[17] - listing[19]
# set()
# listing[19] - listing[17]
# set()
# listing[17] - listing[20]
# set()
# listing[20] - listing[17]
# set()
# listing[17] - listing[21]
# set()
# listing[21] - listing[17]
# set()
# listing[17] - listing[22]
# set()
# listing[22] - listing[17]
# set()
# listing[17] - listing[23]
# set()
# listing[23] - listing[17]
# set()
# listing[17] - listing[24]
# set()
# listing[24] - listing[17]
# set()
# listing[17] - listing[25]
# set()
# listing[25] - listing[17]
# set()
# listing[17] - listing[26]
# set()
# listing[26] - listing[17]
# set()
# listing[17] - listing[27]
# set()
# listing[27] - listing[17]
# set()
# listing[17] - listing[28]
# {'ListAgentEmail'}
# listing[28] - listing[17]
# set()
# listing[18] - listing[19]
# set()
# listing[19] - listing[18]
# set()
# listing[18] - listing[20]
# set()
# listing[20] - listing[18]
# set()
# listing[18] - listing[21]
# set()
# listing[21] - listing[18]
# set()
# listing[18] - listing[22]
# set()
# listing[22] - listing[18]
# set()
# listing[18] - listing[23]
# set()
# listing[23] - listing[18]
# set()
# listing[18] - listing[24]
# set()
# listing[24] - listing[18]
# set()
# listing[18] - listing[25]
# set()
# listing[25] - listing[18]
# set()
# listing[18] - listing[26]
# set()
# listing[26] - listing[18]
# set()
# listing[18] - listing[27]
# set()
# listing[27] - listing[18]
# set()
# listing[18] - listing[28]
# {'ListAgentEmail'}
# listing[28] - listing[18]
# set()
# listing[19] - listing[20]
# set()
# listing[20] - listing[19]
# set()
# listing[19] - listing[21]
# set()
# listing[21] - listing[19]
# set()
# listing[19] - listing[22]
# set()
# listing[22] - listing[19]
# set()
# listing[19] - listing[23]
# set()
# listing[23] - listing[19]
# set()
# listing[19] - listing[24]
# set()
# listing[24] - listing[19]
# set()
# listing[19] - listing[25]
# set()
# listing[25] - listing[19]
# set()
# listing[19] - listing[26]
# set()
# listing[26] - listing[19]
# set()
# listing[19] - listing[27]
# set()
# listing[27] - listing[19]
# set()
# listing[19] - listing[28]
# {'ListAgentEmail'}
# listing[28] - listing[19]
# set()
# listing[20] - listing[21]
# set()
# listing[21] - listing[20]
# set()
# listing[20] - listing[22]
# set()
# listing[22] - listing[20]
# set()
# listing[20] - listing[23]
# set()
# listing[23] - listing[20]
# set()
# listing[20] - listing[24]
# set()
# listing[24] - listing[20]
# set()
# listing[20] - listing[25]
# set()
# listing[25] - listing[20]
# set()
# listing[20] - listing[26]
# set()
# listing[26] - listing[20]
# set()
# listing[20] - listing[27]
# set()
# listing[27] - listing[20]
# set()
# listing[20] - listing[28]
# {'ListAgentEmail'}
# listing[28] - listing[20]
# set()
# listing[21] - listing[22]
# set()
# listing[22] - listing[21]
# set()
# listing[21] - listing[23]
# set()
# listing[23] - listing[21]
# set()
# listing[21] - listing[24]
# set()
# listing[24] - listing[21]
# set()
# listing[21] - listing[25]
# set()
# listing[25] - listing[21]
# set()
# listing[21] - listing[26]
# set()
# listing[26] - listing[21]
# set()
# listing[21] - listing[27]
# set()
# listing[27] - listing[21]
# set()
# listing[21] - listing[28]
# {'ListAgentEmail'}
# listing[28] - listing[21]
# set()
# listing[22] - listing[23]
# set()
# listing[23] - listing[22]
# set()
# listing[22] - listing[24]
# set()
# listing[24] - listing[22]
# set()
# listing[22] - listing[25]
# set()
# listing[25] - listing[22]
# set()
# listing[22] - listing[26]
# set()
# listing[26] - listing[22]
# set()
# listing[22] - listing[27]
# set()
# listing[27] - listing[22]
# set()
# listing[22] - listing[28]
# {'ListAgentEmail'}
# listing[28] - listing[22]
# set()
# listing[23] - listing[24]
# set()
# listing[24] - listing[23]
# set()
# listing[23] - listing[25]
# set()
# listing[25] - listing[23]
# set()
# listing[23] - listing[26]
# set()
# listing[26] - listing[23]
# set()
# listing[23] - listing[27]
# set()
# listing[27] - listing[23]
# set()
# listing[23] - listing[28]
# {'ListAgentEmail'}
# listing[28] - listing[23]
# set()
# listing[24] - listing[25]
# set()
# listing[25] - listing[24]
# set()
# listing[24] - listing[26]
# set()
# listing[26] - listing[24]
# set()
# listing[24] - listing[27]
# set()
# listing[27] - listing[24]
# set()
# listing[24] - listing[28]
# {'ListAgentEmail'}
# listing[28] - listing[24]
# set()
# listing[25] - listing[26]
# set()
# listing[26] - listing[25]
# set()
# listing[25] - listing[27]
# set()
# listing[27] - listing[25]
# set()
# listing[25] - listing[28]
# {'ListAgentEmail'}
# listing[28] - listing[25]
# set()
# listing[26] - listing[27]
# set()
# listing[27] - listing[26]
# set()
# listing[26] - listing[28]
# {'ListAgentEmail'}
# listing[28] - listing[26]
# set()
# listing[27] - listing[28]
# {'ListAgentEmail'}
# listing[28] - listing[27]
# set()

# %%
df_list = pd.concat(listings)

print(df_list.shape)

df_list.head()
# Out:
# (897099, 84)
#    OriginalListPrice  ListingKey                        ListAgentEmail  \
# 0            90000.0  1075010398                miriamlara03@gmail.com
# 1          1500000.0  1074974457                  janelle@judsonre.com
# 2          1340000.0  1074973329                    haleh360@Gmail.com
# 3          2500000.0  1074954552  Reneechen@yourhomesoldguaranteed.com
# 4          3150000.0  1074936537                      anader@dppre.com
#
#   CloseDate  ClosePrice ListAgentFirstName ListAgentLastName   Latitude  \
# 0       NaN         NaN             Miriam              Lara  34.097939
# 1       NaN         NaN            Janelle            Judson  33.121241
# 2       NaN         NaN              Haleh       Dowlatshahi  34.052207
# 3       NaN         NaN              Renee              Chen  33.496363
# 4       NaN         NaN           Margaret             Nader  34.119345
#
#     Longitude                UnparsedAddress  ... MainLevelBedrooms  \
# 0 -117.909653                1045 N Azusa 61  ...               NaN
# 1 -117.081614                            NaN  ...               NaN
# 2 -118.408445  2220 Avenue Of The Stars 2704  ...               NaN
# 3 -117.691677                   16 Palisades  ...               0.0
# 4 -118.111254              1615 Waverly Road  ...               NaN
#
#    NewConstructionYN  GarageSpaces     HighSchoolDistrict PostalCode  \
# 0                NaN           2.0  Covina Valley Unified      91722
# 1                NaN           NaN                    NaN      92025
# 2              False           NaN                    NaN      90067
# 3              False           3.0     Capistrano Unified      92677
# 4                NaN           2.0                    NaN      91108
#
#   BuyerOfficeName.1 AssociationFee LotSizeSquareFeet  \
# 0               NaN            0.0               NaN
# 1               NaN            0.0               NaN
# 2               NaN         2105.0          177861.0
# 3               NaN          254.0            5300.0
# 4               NaN            NaN            9404.0
#
#   MiddleOrJuniorSchoolDistrict              UnparsedAddress.1
# 0                          NaN                1045 N Azusa 61
# 1                          NaN                            NaN
# 2                          NaN  2220 Avenue Of The Stars 2704
# 3                          NaN                   16 Palisades
# 4                          NaN              1615 Waverly Road
#
# [5 rows x 84 columns]

# %%
df_list.columns
# Out:
# Index(['OriginalListPrice', 'ListingKey', 'ListAgentEmail', 'CloseDate',
#        'ClosePrice', 'ListAgentFirstName', 'ListAgentLastName', 'Latitude',
#        'Longitude', 'UnparsedAddress', 'PropertyType', 'LivingArea',
#        'ListPrice', 'DaysOnMarket', 'ListOfficeName', 'BuyerOfficeName',
#        'CoListOfficeName', 'ListAgentFullName', 'CoListAgentFirstName',
#        'CoListAgentLastName', 'BuyerAgentMlsId', 'BuyerAgentFirstName',
#        'BuyerAgentLastName', 'FireplacesTotal', 'AssociationFeeFrequency',
#        'AboveGradeFinishedArea', 'ListingKeyNumeric', 'MLSAreaMajor',
#        'TaxAnnualAmount', 'CountyOrParish', 'PropertyType.1', 'MlsStatus',
#        'ElementarySchool', 'ListAgentFirstName.1', 'AttachedGarageYN',
#        'ParkingTotal', 'BuilderName', 'PropertySubType', 'LotSizeAcres',
#        'SubdivisionName', 'BuyerOfficeAOR', 'YearBuilt', 'DaysOnMarket.1',
#        'BuyerAgencyCompensationType', 'StreetNumberNumeric', 'LivingArea.1',
#        'ListingId', 'BathroomsTotalInteger', 'City', 'BuyerAgencyCompensation',
#        'TaxYear', 'BuildingAreaTotal', 'BedroomsTotal',
#        'ContractStatusChangeDate', 'Longitude.1', 'ElementarySchoolDistrict',
#        'CoBuyerAgentFirstName', 'PurchaseContractDate', 'ListingContractDate',
#        'BelowGradeFinishedArea', 'BusinessType', 'Latitude.1', 'ListPrice.1',
#        'StateOrProvince', 'CoveredSpaces', 'MiddleOrJuniorSchool',
#        'FireplaceYN', 'Stories', 'HighSchool', 'Levels', 'ListAgentLastName.1',
#        'CloseDate.1', 'LotSizeDimensions', 'LotSizeArea', 'MainLevelBedrooms',
#        'NewConstructionYN', 'GarageSpaces', 'HighSchoolDistrict', 'PostalCode',
#        'BuyerOfficeName.1', 'AssociationFee', 'LotSizeSquareFeet',
#        'MiddleOrJuniorSchoolDistrict', 'UnparsedAddress.1'],
#       dtype='str')

# %%
duplicate_list = df_list["ListPrice.1"] == df_list["ListPrice"]
print("Duplicate listing price?", duplicate_list.unique())

print()
duplicate_propertytype = df_list["PropertyType"] == df_list["PropertyType.1"]
print("Dubplicate property type?", duplicate_propertytype.unique())

print()
duplicate_closedate = df_list["CloseDate"] == df_list["CloseDate.1"]
print("Dubplicate close date?", duplicate_closedate.unique())

print()
duplicate_living_area = df_list["LivingArea"] == df_list["LivingArea.1"]
print("Duplicate living area?", duplicate_living_area.unique())

print()
duplicate_days_market = df_list["DaysOnMarket"] == df_list["DaysOnMarket.1"]
print("Duplicate days on market?", duplicate_days_market.unique())

print()
duplicate_latitude = df_list["Latitude"] == df_list["Latitude.1"]
print("Duplicate latitude?", duplicate_latitude.unique())

print()
duplicate_longitude = df_list["Longitude"] == df_list["Longitude.1"]
print("Duplicate longitude?", duplicate_longitude.unique())

print()
duplicate_address = df_list["UnparsedAddress"] == df_list["UnparsedAddress.1"]
print("Duplicate address?", duplicate_address.unique())

print()
duplicate_agent_first_name = df_list["ListAgentFirstName"] == df_list["ListAgentFirstName.1"]
print("Duplicate agent first name?", duplicate_agent_first_name.unique())

print()
duplicate_agent_last_name = df_list["ListAgentLastName"] == df_list["ListAgentLastName.1"]
print("Duplicate agent last name?", duplicate_agent_last_name.unique())

print()
duplicate_buyer_office_name = df_list["BuyerOfficeName"] == df_list["BuyerOfficeName.1"]
print("Duplicate buyer office name?", duplicate_buyer_office_name.unique())
# Out:
# Duplicate listing price? [ True False]
#
# Dubplicate property type? [ True]
#
# Dubplicate close date? [False  True]
#
# Duplicate living area? [ True False]
#
# Duplicate days on market? [ True]
#
# Duplicate latitude? [ True False]
#
# Duplicate longitude? [ True False]
#
# Duplicate address? [ True False]
#
# Duplicate agent first name? [ True False]
#
# Duplicate agent last name? [ True False]
#
# Duplicate buyer office name? [False  True]

# %%
different_listprice = df_list[df_list["ListPrice.1"] != df_list["ListPrice"]]

different_listprice[["ListingKey", "ListPrice", "ListPrice.1"]]
# Out:
#        ListingKey  ListPrice  ListPrice.1
# 57     1069730664        NaN          NaN
# 346    1062101812        NaN          NaN
# 383    1062034615        NaN          NaN
# 1088   1060187374        NaN          NaN
# 2701   1059600517        NaN          NaN
# ...           ...        ...          ...
# 33497  1159293218        NaN          NaN
# 33975  1159256805        NaN          NaN
# 33982  1159256279        NaN          NaN
# 33996  1159255951        NaN          NaN
# 34020  1159254998        NaN          NaN
#
# [2209 rows x 3 columns]

# %%
different_closedate = df_list[df_list["CloseDate.1"] != df_list["CloseDate"]]
print("Different CloseDate rows:", different_closedate.shape[0])
print("Value that are different:", different_closedate["CloseDate"].unique())
different_closedate[["ListingKey", "CloseDate", "CloseDate.1"]]
# Out:
# Different CloseDate rows: 637068
# Value that are different: <StringArray>
# [nan]
# Length: 1, dtype: str
#        ListingKey CloseDate CloseDate.1
# 0      1075010398       NaN         NaN
# 1      1074974457       NaN         NaN
# 2      1074973329       NaN         NaN
# 3      1074954552       NaN         NaN
# 4      1074936537       NaN         NaN
# ...           ...       ...         ...
# 36195  1154277796       NaN         NaN
# 36196  1153629738       NaN         NaN
# 36198  1151741919       NaN         NaN
# 36199  1146590110       NaN         NaN
# 36200  1136798684       NaN         NaN
#
# [637068 rows x 3 columns]

# %%
different_latitude = df_list[df_list["Latitude.1"] != df_list["Latitude"]]
print("Different Latitude rows:", different_latitude.shape[0])
print("Value that are different:", different_latitude["Latitude"].unique())
different_latitude[["ListingKey", "Latitude", "Latitude.1"]]
# Out:
# Different Latitude rows: 112569
# Value that are different: [nan]
#        ListingKey  Latitude  Latitude.1
# 50     1071104851       NaN         NaN
# 67     1069615513       NaN         NaN
# 76     1068189553       NaN         NaN
# 90     1067816924       NaN         NaN
# 125    1065257776       NaN         NaN
# ...           ...       ...         ...
# 36174  1157413891       NaN         NaN
# 36175  1157411991       NaN         NaN
# 36185  1156787991       NaN         NaN
# 36191  1155792318       NaN         NaN
# 36197  1153102507       NaN         NaN
#
# [112569 rows x 3 columns]

# %%
list_keep_col = [
   # IDs
    "ListingKey",
    "ListingKeyNumeric",
    "ListingId",

    # Dates
    "CloseDate",
    "ListingContractDate",
    "PurchaseContractDate",
    "ContractStatusChangeDate",

    # Price fields
    "ClosePrice",
    "ListPrice",
    "OriginalListPrice",

    # Property characteristics
    "PropertyType",
    "PropertySubType",
    "LivingArea",
    "BedroomsTotal",
    "BathroomsTotalInteger",
    "YearBuilt",
    "DaysOnMarket",
    "LotSizeSquareFeet",

    # Location
    "Latitude",
    "Longitude",
    "UnparsedAddress",
    "City",
    "CountyOrParish",
    "PostalCode",
    "StateOrProvince",
    "MLSAreaMajor",

    # School
    "ElementarySchool",
    "ElementarySchoolDistrict",
    "MiddleOrJuniorSchool",
    "MiddleOrJuniorSchoolDistrict",
    "HighSchool",
    "HighSchoolDistrict",

    # Agent / office competitive analysis
    "ListAgentFirstName",
    "ListAgentLastName",
    "ListAgentFullName",
    "ListOfficeName",
    "BuyerAgentFirstName",
    "BuyerAgentLastName",
    "BuyerOfficeName",

    # Useful property features
    "GarageSpaces",
    "ParkingTotal",
    "FireplacesTotal",
    "FireplaceYN",
    "AttachedGarageYN",
    "NewConstructionYN",
    "Levels",
    "Stories",
    "TaxAnnualAmount",
    "TaxYear",

    # Status
    "MlsStatus",
    "BusinessType",

    # Additional property / builder / neighborhood information
    "BuilderName",
    "SubdivisionName"
]

# %%
df_list = df_list.drop(
    columns=[
        # Personal/contact info
        "ListAgentEmail",

        # Agent extra information as redundent.
        # Already included agent and office names
        "CoListOfficeName",
        "CoListAgentFirstName",
        "CoListAgentLastName",
        "CoBuyerAgentFirstName",
        "BuyerAgentMlsId",
        "BuyerOfficeAOR",
        "AssociationFeeFrequency",
        "AssociationFee",

        # Extra information of property features
        "AboveGradeFinishedArea",
        "BelowGradeFinishedArea",
        "BuildingAreaTotal",
        "LotSizeAcres",
        "LotSizeDimensions",
        "LotSizeArea",
        "MainLevelBedrooms",
        "StreetNumberNumeric",
        "CoveredSpaces",

        # Duplicate columns of property features
        "PropertyType.1",
        "ListAgentFirstName.1",
        "DaysOnMarket.1",
        "LivingArea.1",
        "Longitude.1",
        "Latitude.1",
        "ListPrice.1",
        "ListAgentLastName.1",
        "CloseDate.1",
        "BuyerOfficeName.1",
        "UnparsedAddress.1"
        ]
    )
df_list.shape
# Out:
# (897099, 55)

# %%
df_list = df_list[df_list["PropertyType"] == "Residential"]

print("List of property types:")
print(df_list["PropertyType"].unique())
# Out:
# List of property types:
# <StringArray>
# ['Residential']
# Length: 1, dtype: str

# %%
print(df_list[df_list.duplicated(keep=False)])
print("Total duplicate rows:", df_list["ListingKey"].duplicated().sum())
# Out:
# Empty DataFrame
# Columns: [OriginalListPrice, ListingKey, CloseDate, ClosePrice, ListAgentFirstName, ListAgentLastName, Latitude, Longitude, UnparsedAddress, PropertyType, LivingArea, ListPrice, DaysOnMarket, ListOfficeName, BuyerOfficeName, ListAgentFullName, BuyerAgentFirstName, BuyerAgentLastName, FireplacesTotal, ListingKeyNumeric, MLSAreaMajor, TaxAnnualAmount, CountyOrParish, MlsStatus, ElementarySchool, AttachedGarageYN, ParkingTotal, BuilderName, PropertySubType, SubdivisionName, YearBuilt, BuyerAgencyCompensationType, ListingId, BathroomsTotalInteger, City, BuyerAgencyCompensation, TaxYear, BedroomsTotal, ContractStatusChangeDate, ElementarySchoolDistrict, PurchaseContractDate, ListingContractDate, BusinessType, StateOrProvince, MiddleOrJuniorSchool, FireplaceYN, Stories, HighSchool, Levels, NewConstructionYN, GarageSpaces, HighSchoolDistrict, PostalCode, LotSizeSquareFeet, MiddleOrJuniorSchoolDistrict]
# Index: []
#
# [0 rows x 55 columns]
# Total duplicate rows: 173

# %% [markdown]
# There are 139 duplicate listing key appears more than once, and there are no fully duplicate rows of properties. This suggests that some features are different, such as market status, days on market, list price, close price, or other updated fields in listing data.

# %%
df_sold.to_csv("sold_residential.csv", index=False)
df_list.to_csv("listing_residential.csv", index=False)
